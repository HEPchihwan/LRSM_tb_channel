# %% [markdown]
# ## lhe 에서 b 찾아와서 실제 ak4에 해당하는거 찾기
# ### 그전에 ak4 갯수 몇갠지 대충 보기
# ## 그리고 btagger 결과랑 잘 맞는지

# %%
from importlib import import_module
import os
import sys
import argparse
import linecache
import uproot
import vector
import math
import numpy as np
import matplotlib.pyplot as plt
import awkward as ak

sample = "/data6/Users/achihwan/LRSM_tb_channel/SAMPLEPRODUCTION/WRtoNMutoMuMuTB-HadTop_MWR-5000_MN-4900_13p6TeV/Run3Summer22NanoAODv12_WRtoNMutoMuMuTB-HadTop_MWR-5000_MN-4900_13p6TeV_1.root"
file = uproot.open(sample)
events = file["Events"]
keys = events.keys()


lhe_pdgid = events["LHEPart_pdgId"].array()
lhe_pt = events["LHEPart_pt"].array()
lhe_eta = events["LHEPart_eta"].array()
lhe_phi = events["LHEPart_phi"].array()
lhe_mass = events["LHEPart_mass"].array()
lhe_status = events["LHEPart_status"].array()

ak4_eta = events["Jet_eta"].array()
ak4_phi = events["Jet_phi"].array()
ak4_pt = events["Jet_pt"].array()
ak4_flavor = events["Jet_hadronFlavour"].array()
ak4_mass = events["Jet_mass"].array()
btag = events["Jet_btagPNetB"].array()

## Fatjet 
fatjet_pt = events["FatJet_pt"].array()
fatjet_eta = events["FatJet_eta"].array()
fatjet_phi = events["FatJet_phi"].array()
fatjet_mass = events["FatJet_mass"].array()

gen_pdgid = events["GenPart_pdgId"].array()
gen_pt = events["GenPart_pt"].array()
gen_eta = events["GenPart_eta"].array()
gen_phi = events["GenPart_phi"].array()
gen_mass = events["GenPart_mass"].array()

muon_pt = events["Muon_pt"].array()
muon_eta = events["Muon_eta"].array()
muon_phi = events["Muon_phi"].array()
muon_mass = events["Muon_mass"].array()
def delta_phi_cal(phi1, phi2):
    d = phi1 - phi2
    # wrap to [-π, +π]
    return (d + np.pi) % (2*np.pi) - np.pi

def delta_r(eta1, phi1, eta2, phi2):
    d_eta = eta1 - eta2
    d_phi = delta_phi(phi1, phi2)
    return np.sqrt(d_eta**2 + d_phi**2)

# mask 
bottom_mask = (lhe_pdgid == 5) | (lhe_pdgid == -5)
bottom_eta = lhe_eta[bottom_mask]
bottom_phi = lhe_phi[bottom_mask]
bottom_pt = lhe_pt[bottom_mask]
bottom_mass = lhe_mass[bottom_mask]

topmask = (gen_pdgid == 6) | (gen_pdgid == -6)
top_eta = gen_eta[topmask]
top_phi1 = gen_phi[topmask]
top_pt = gen_pt[topmask]
top_mass = gen_mass[topmask]

top_etass = top_eta[:, 0] # top quark 1 = WR* mother
top_phi1ss = top_phi1[:, 0]
top_ptss = top_pt[:, 0]
top_massss = top_mass[:, 0]

bottompt = bottom_pt[:, 1]#bottom quark 1 = WR* mother
bottometa = bottom_eta[:, 1]
bottomphi = bottom_phi[:, 1]
bottommass = bottom_mass[:, 1]

muon_mask = (lhe_pdgid == 13) | (lhe_pdgid == -13)
muon_pt = lhe_pt[muon_mask]
muon_eta = lhe_eta[muon_mask]
muon_phi = lhe_phi[muon_mask]
muon_mass = lhe_mass[muon_mask]

n_mother_muon_mass = muon_mass[:,0] # muon 1 = WR* mother
n_mother_muon_pt = muon_pt[:,0] # muon 1 = WR* mother
n_mother_muon_eta = muon_eta[:,0]
n_mother_muon_phi = muon_phi[:,0]

WR_mother_muon_mass = muon_mass[:,1] # muon 2 = WR* mother
WR_mother_muon_pt = muon_pt[:,1] # muon 2 = WR* mother
WR_mother_muon_eta = muon_eta[:,1]
WR_mother_muon_phi = muon_phi[:,1]  
#####
dr_list_4u = []
idx_list_4u = []
tag_list_4u = [] ## for minimum ΔR jet
flavor_list_4u = [] ## for minimum ΔR jet
mass_list_4u = [] ## for minimum ΔR jet

dr_next_4u = []
idx_next_4u = []
tag_next_4u = [] ## for next minimum ΔR jet
flavor_next_4u = [] ## for next minimum ΔR jet
mass_next_4u = [] ## for next minimum ΔR jet
######
dr_list_4d = []
idx_list_4d = []
tag_list_4d = [] ## for minimum ΔR jet
tag_list_4d_pt = []
tag_list_4d_dr = []
flavor_list_4d = [] ## for minimum ΔR jet
mass_list_4d = [] ## for minimum ΔR jet

dr_next_4d = []
idx_next_4d = []
tag_next_4d = [] ## for next minimum ΔR jet
tag_next_4d_pt = []
tag_next_4d_dr = []
flavor_next_4d = [] ## for next minimum ΔR jet
mass_next_4d = [] ## for next minimum ΔR jet

dr_list_4d_btag = []
idx_list_4d_btag = []
tag_list_4d_btag = [] ## for minimum ΔR jet
flavor_list_4d_btag = [] ## for minimum ΔR jet
mass_list_4d_btag = [] ## for minimum ΔR jet

dr_list_4d_ntag = []
idx_list_4d_ntag = []
tag_list_4d_ntag = [] ## for minimum ΔR jet
flavor_list_4d_ntag = [] ## for minimum ΔR jet
mass_list_4d_ntag = [] ## for minimum ΔR jet

dr_next_4d_btag = []
idx_next_4d_btag = []
tag_next_4d_btag = [] ## for next minimum ΔR jet
flavor_next_4d_btag = [] ## for next minimum ΔR jet
mass_next_4d_btag = [] ## for next minimum ΔR jet

##ΔR distribution with ak4 and ak8 jet 
dr_ak8_ak4_closet = []
dr_ak8_ak4_next = []
dphi_ak8_ak4_closet = []
dphi_ak8_ak4_next = []
dr_b_ak8_closest = []

N_reco_masss = []
bottompts = []
real_mass = []


ak4_mass_closest = []
for i in range(len(bottompt)):
        if (len(ak4_mass[i]) == 0) or ((bottompt[i]) == False) or (len(top_eta[i]) < 2):
            continue
        delta_eta = bottometa[i] - ak4_eta[i]
        delta_phi = bottomphi[i] - ak4_phi[i] 
        delta_phi = (delta_phi + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
        dr = np.sqrt(delta_eta**2 + delta_phi**2)

        top_etas = top_eta[i][0]
        top_phi = top_phi1[i][0]
        delta_etas = fatjet_eta[i] - top_etas
        delta_phis = fatjet_phi[i] -top_phi 
        delta_phis = (delta_phis + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
        dr_jet = np.sqrt(delta_etas**2 + delta_phis**2)

        

        if ((len(dr) >0 ) and len(dr_jet) > 0):
            idx_ak8 = np.argsort(dr_jet)[0] ## top 과 제일 가까운 fatjet
            idx = np.argsort(dr)[0] ## bottom과 제일 가까운 ak4 jet
            next_idx = np.argsort(dr)[1] ## bottom과 두번째로 가까운 ak4 jet
            r = dr[idx]
            #print(fatjet_eta[i][idx_ak8], bottometa[i])
            deta_b_ak8 = fatjet_eta[i][idx_ak8] - bottometa[i]
            dphi_b_ak8 = fatjet_phi[i][idx_ak8] - bottomphi[i]
            dphi_b_ak8 = (dphi_b_ak8 + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
            dr_b_ak8 = np.sqrt(deta_b_ak8**2 + dphi_b_ak8**2)
            dr_b_ak8_closest.append(dr_b_ak8)
            #ΔR between bottom ak4 jet and top fatjet
            delta_eta_b_ak8 = fatjet_eta[i][idx_ak8] - ak4_eta[i]
            delta_phi_b_ak8 = fatjet_phi[i][idx_ak8] - ak4_phi[i]
            delta_phi_b_ak8 = (delta_phi_b_ak8 + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
            dr_ak4_ak8 = np.sqrt(delta_eta_b_ak8**2 + delta_phi_b_ak8**2)

            ak4_mass_closest.append(ak4_mass[i][idx]) 
            if dr_b_ak8 > 1.2: 
                if r > 0.4: 
                    idx_list_4u.append(idx)
                    dr_list_4u.append(dr[idx])
                    idx_next_4u.append(next_idx)
                    dr_next_4u.append(dr[next_idx])
                    ## flavor , tagger score check
                
                    tag_score = btag[i][idx]
                    tag_list_4u.append(tag_score)
                    flavor = ak4_flavor[i][idx]
                    flavor_list_4u.append(flavor)
                    tag_next_score = btag[i][next_idx]
                    tag_next_4u.append(tag_next_score)
                    flavor_next = ak4_flavor[i][next_idx]
                    flavor_next_4u.append(flavor_next)
                    mass_list_4u.append(ak4_mass[i][idx])
                    mass_next_4u.append(ak4_mass[i][next_idx])
                if r < 0.4: 
                    idx_list_4d.append(idx)
                    dr_list_4d.append(dr[idx])
                    idx_next_4d.append(next_idx)
                    dr_next_4d.append(dr[next_idx])
                    ## flavor , tagger score check
                    tag_score = btag[i][idx]
                    tag_next_score = btag[i][next_idx]
                    flavor =  ak4_flavor[i][idx]
                    flavor_next = ak4_flavor[i][next_idx]
                    tag_list_4d.append(tag_score)
                    
                    flavor_list_4d.append(flavor)
                    tag_next_4d.append(tag_next_score)
                    
                    flavor_next_4d.append(flavor_next)
                    mass_list_4d.append(ak4_mass[i][idx])
                    mass_next_4d.append(ak4_mass[i][next_idx])

                    

                    if tag_score > 0.8: # tag score up 0.8
                        tag_list_4d_pt.append(ak4_pt[i][idx])
                        tag_list_4d_dr.append(dr[idx])
                        tag_next_4d_pt.append(ak4_pt[i][next_idx])
                        tag_next_4d_dr.append(dr[next_idx])
                        
                        dr_ak8_ak4_closet.append(dr_ak4_ak8[idx])
                        dr_ak8_ak4_next.append(dr_ak4_ak8[next_idx])
                        dphi_ak8_ak4_closet.append(delta_phi_cal(fatjet_phi[i][idx_ak8], ak4_phi[i][idx]))
                        dphi_ak8_ak4_next.append(delta_phi_cal(fatjet_phi[i][idx_ak8], ak4_phi[i][next_idx]))
                        idx_list_4d_btag.append(idx)
                        dr_list_4d_btag.append(dr[idx])
                        tag_list_4d_btag.append(tag_score)
                        flavor = ak4_flavor[i][idx]
                        flavor_list_4d_btag.append(flavor)
                        mass_list_4d_btag.append(ak4_mass[i][idx])
                        if len(top_pt) > 0 :
                            gen_top_mass = vector.array({"pt": top_ptss[i],
                                                    "eta": top_etass[i],
                                                    "phi": top_phi1ss[i],
                                                    "mass": top_massss[i]})
                        top_mass = vector.array({"pt": fatjet_pt[i][idx_ak8],
                                                "eta": fatjet_eta[i][idx_ak8],
                                                "phi": fatjet_phi[i][idx_ak8],
                                                "mass": fatjet_mass[i][idx_ak8]})
                        bottom_mass = vector.array({"pt": ak4_mass[i][idx],
                                                "eta": ak4_eta[i][idx],
                                                "phi": ak4_phi[i][idx],
                                                "mass":ak4_mass[i][idx]})
                        n_mother_muon = vector.array({"pt": n_mother_muon_pt[i],
                                                "eta": n_mother_muon_eta[i],
                                                "phi": n_mother_muon_phi[i],
                                                "mass": n_mother_muon_mass[i]})
                        WR_mother_muon = vector.array({"pt": WR_mother_muon_pt[i],
                                                "eta": WR_mother_muon_eta[i],
                                                "phi": WR_mother_muon_phi[i],
                                                "mass": WR_mother_muon_mass[i]})
                        real_bottom_mass = vector.array({"pt": bottompt[i],
                                                "eta": bottometa[i],
                                                "phi": bottomphi[i],
                                                "mass": bottommass[i]})
                        muon1_mass = vector.array({"pt": muon_pt[i][0],
                                                "eta": muon_eta[i][0],
                                                "phi": muon_phi[i][0],
                                                "mass": muon_mass[i][0]})
                        muon2_mass = vector.array({"pt": muon_pt[i][1],
                                                "eta": muon_eta[i][1],
                                                "phi": muon_phi[i][1],
                                                "mass": muon_mass[i][1]})
                        if len(top_pt[i]) > 0:
                            N_reco_mass = (gen_top_mass + bottom_mass+muon1_mass+muon2_mass).mass
                            real_reco_mass = (gen_top_mass + real_bottom_mass+muon1_mass+muon2_mass ).mass
                            real_mass.append(real_reco_mass)
                            N_reco_masss.append(N_reco_mass)
                            bottompts.append(ak4_pt[i][idx])
                        
                    if tag_score < 0.8:    # dr < 0.4 but tag score down 0.8
                        dr_list_4d_ntag.append(dr[idx])
                        tag_score = btag[i][idx]
                        tag_list_4d_ntag.append(tag_score)
                        flavor = ak4_flavor[i][idx]
                        flavor_list_4d_ntag.append(flavor)
                        mass_list_4d_ntag.append(ak4_mass[i][idx])
                    
                ## ak8 안에 bottom jet이 있으면 탈락 


            
            

            

N_reco_masss = ak.flatten(N_reco_masss)
real_mass = ak.flatten(real_mass)
fig , axs = plt.subplots(6, 3 , figsize=(20, 35))
axs[0,0].hist(dr_list_4u, bins=100, range=(0, 3), histtype='step', label='Minimum ΔR Jet')
axs[0,0].hist(dr_next_4u, bins=100, range=(0, 3), histtype='step', label='Next Minimum ΔR Jet')
axs[0,0].set_xlabel('ΔR')
axs[0,0].set_ylabel('Number of Jets')
axs[0,0].set_title('AK4 Jets with ΔR > 0.4')
axs[0,1].hist(dr_list_4d, bins=100, range=(0, 3), histtype='step', label='Minimum ΔR Jet')
axs[0,1].hist(dr_next_4d, bins=100, range=(0, 3), histtype='step', label='Next Minimum ΔR Jet')
axs[0,1].set_xlabel('ΔR')
axs[0,1].set_ylabel('Number of Jets')
axs[0,1].set_title('AK4 Jets with ΔR < 0.4')
axs[0,1].axvline(x=0.4, color='black', linestyle='--', label='ΔR = 0.4')
axs[0,2].hist(dr_list_4d_btag, bins=100, range=(0, 3), histtype='step', label='Minimum ΔR Jet with BTag Score > 0.8')
axs[0,2].hist(dr_list_4d_ntag, bins=100, range=(0, 3), histtype='step', label='Minimum ΔR Jet with BTag Score < 0.8')
axs[0,2].set_xlabel('ΔR')
axs[0,2].set_ylabel('Number of Jets')
axs[0,2].set_title('AK4 Jets ΔR < 0.4 Score > 0.8')


axs[1,0].hist(tag_list_4d, bins=100, range=(0, 1), histtype='step', label='Minimum ΔR Jet BTag Score')
axs[1,0].hist(tag_next_4d, bins=100, range=(0, 1), histtype='step', label='Next Minimum ΔR Jet BTag Score')
axs[1,0].set_xlabel('BTag Score')
axs[1,0].set_ylabel('Number of Jets')
axs[1,0].set_title('AK4 Jets with ΔR < 0.4')
axs[1,0].legend()

axs[1,1].hist(tag_list_4d_pt, bins=100, range=(0, 2000), histtype='step', label='Minimum ΔR Jet PT, score > 0.8')
axs[1,1].hist(tag_next_4d_pt, bins=100, range=(0, 2000), histtype='step', label='Next Minimum ΔR Jet PT, score > 0.8')
axs[1,1].set_xlabel('Jet PT (GeV)')
axs[1,1].set_ylabel('Number of Jets')
axs[1,1].set_title('AK4 Jets with ΔR < 0.4')
axs[1,1].legend()

axs[1,2].hist(tag_list_4d_dr, bins=100, range=(0, 3), histtype='step', label='Minimum ΔR Jet ΔR , score > 0.8')
axs[1,2].hist(tag_next_4d_dr, bins=100, range=(0, 3), histtype='step', label='Next Minimum ΔR Jet ΔR , score > 0.8')
axs[1,2].set_xlabel('Jet ΔR')
axs[1,2].set_ylabel('Number of Jets')
axs[1,2].set_title('AK4 Jets with ΔR < 0.4')
axs[1,2].legend()   


axs[2,0].hist(flavor_list_4u, bins=100, range=(0, 5), histtype='step', label='Jet Flavor')
axs[2,0].hist(flavor_next_4u, bins=100, range=(0, 5), histtype='step', label='Next Jet Flavor')
axs[2,0].set_xlabel('Jet Flavor')
axs[2,0].set_ylabel('Number of Jets')
axs[2,0].set_title('AK4 Jets with ΔR > 0.4')
axs[2,1].hist(flavor_list_4d, bins=100, range=(0, 5), histtype='step', label='Minimum ΔR Jet Flavor')
axs[2,1].hist(flavor_next_4d, bins=100, range=(0, 5), histtype='step', label='Next Minimum ΔR Jet Flavor')
axs[2,1].set_xlabel('Jet Flavor')
axs[2,1].set_ylabel('Number of Jets')
axs[2,1].set_title('AK4 Jets with ΔR < 0.4')
axs[2,1].legend()

axs[2,2].hist(flavor_list_4d_btag, bins=100, range=(0, 5), histtype='step', label='Jet Flavor')
axs[2,2].hist(flavor_list_4d_ntag, bins=100, range=(0, 5), histtype='step', label='Next Jet Flavor')
axs[2,2].set_xlabel('Jet Flavor')
axs[2,2].set_ylabel('Number of Jets')
axs[2,2].set_title('AK4 Jets ΔR < 0.4 Score > 0.8')
axs[3,0].hist(mass_list_4u, bins=100, range=(0, 200), histtype='step', label='Jet Mass')
axs[3,0].hist(mass_next_4u, bins=100, range=(0, 200), histtype='step', label='Next Jet Mass')
axs[3,0].set_xlabel('Jet Mass (GeV)')
axs[3,0].set_ylabel('Number of Jets')
axs[3,1].hist(mass_list_4d, bins=100, range=(0, 200), histtype='step', label='Minimum ΔR Jet Mass')
axs[3,1].hist(mass_next_4d, bins=100, range=(0, 200), histtype='step', label='Next Minimum ΔR Jet Mass')
axs[3,1].set_xlabel('Jet Mass (GeV)')   
axs[3,1].set_ylabel('Number of Jets')
axs[3,1].set_title('AK4 Jet mass with ΔR < 0.4')
axs[3,1].legend()
axs[3,2].hist(mass_list_4d_btag, bins=100, range=(0, 200), histtype='step', label='Jet Mass')
axs[3,2].hist(mass_list_4d_ntag, bins=100, range=(0, 200), histtype='step', label='Next Jet Mass')
axs[3,2].set_xlabel('Jet Mass (GeV)')
axs[3,2].set_ylabel('Number of Jets')
axs[4,0].hist(real_mass, bins=30, range=(0, 6000), histtype='step', label='LHE lepton, bottom + gen top Reconstructed Mass')
axs[4,0].hist(N_reco_masss, bins=30, range=(0, 6000), histtype='step', label='LHE lepton + AK4 bjet + gen top Reconstructed Mass')
axs[4,0].set_xlabel('Reconstructed Mass (GeV)')

axs[4,0].set_ylabel('Number of Events')
axs[4,0].set_title('Reconstructed Mass Distribution')
#axs[4,1].hist(bottompt, bins=30, range=(0, 2000), histtype='step', label='Bottom Jet PT from LHE')
axs[4,1].hist(bottompts, bins=100, range=(0, 2000), histtype='step', label='Bottom Jet PT')
axs[4,1].axvline(x=30, color='black', linestyle='--', label='PT = 30 GeV')


axs[4 ,1].legend()
axs[4,1].set_xlabel('Bottom Jet PT (GeV)')
axs[4,2].hist(dr_ak8_ak4_closet, bins=100, range=(0, 5), histtype='step', label='ΔR between AK8 and Closest AK4 Jet, score > 0.8')
axs[4,2].hist(dr_ak8_ak4_next, bins=100, range=(0, 5), histtype='step', label='ΔR between AK8 and Next Closest AK4 Jet, score > 0.8')
axs[4,2].set_xlabel('AK4 ΔR closest to AK8 ')
axs[4,2].legend()

axs[5,0].hist(dphi_ak8_ak4_closet, bins=100, range=(-np.pi, np.pi), histtype='step', label='Δφ between AK8 and Closest AK4 Jet')
axs[5,0].hist(dphi_ak8_ak4_next, bins=100, range=(-np.pi, np.pi), histtype='step', label='Δφ between AK8 and Next Closest AK4 Jet')
axs[5,0].set_xlabel('AK4 Δφ closest to AK8 ')
axs[5,0].set_ylabel('Number of Jets')
axs[5,0].set_title('Δφ Distribution between AK8 and Closest AK4 Jet, score > 0.8')
axs[5,0].legend()

axs[5,2].hist(dr_b_ak8_closest, bins=100, range=(0, 5), histtype='step', label='ΔR between Bottom and Closest AK8 Jet')
axs[5,2].set_xlabel('LHE b ΔR to AK8 ')
axs[5, 1].set_xlabel('Bottom Mass (GeV)')
axs[5,1].hist(bottommass , bins=30, range=(0, 200), histtype='step', label='Bottom Mass from LHE')
axs[5,1].hist(ak4_mass_closest, bins=30, range=(0, 200), histtype='step', label='Closest AK4 Jet Mass')

axs[5, 1].legend()
axs[0,1].legend()
axs[0,2].legend()
#일단 제일 작은 ΔR을 갖는 jet를 찾고 그게 ak8 보다 1.2 이상 벌어져야 함 . 
## 두번째 히스토 그램은 두번째로 큰 r이 유효할 수도 있는지 확인 하는거 
## 세번째 히스토그램은 signal b와 0.4이내에 있는 btag 0.8 이상과 이하 비교
print(len(dr_list_4d_btag)) ## 500개 중에서 몇개 사용 가능한지 ( 0.4 이내에 있고 btag 0.8 이상인 것 )
print(N_reco_masss)
print(idx_list_4d_btag)
# Out:
# 104
# [3.98e+03, 3.61e+03, 2.46e+03, 2.19e+03, ..., 2.88e+03, 3.32e+03, 3.11e+03]
# [np.int64(2), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(2), np.int64(1), np.int64(2), np.int64(2), np.int64(2), np.int64(0), np.int64(1), np.int64(2), np.int64(2), np.int64(3), np.int64(1), np.int64(0), np.int64(2), np.int64(0), np.int64(0), np.int64(3), np.int64(1), np.int64(1), np.int64(0), np.int64(2), np.int64(2), np.int64(3), np.int64(0), np.int64(0), np.int64(2), np.int64(1), np.int64(2), np.int64(0), np.int64(1), np.int64(2), np.int64(2), np.int64(2), np.int64(2), np.int64(1), np.int64(2), np.int64(1), np.int64(2), np.int64(0), np.int64(2), np.int64(1), np.int64(0), np.int64(1), np.int64(2), np.int64(1), np.int64(1), np.int64(2), np.int64(2), np.int64(2), np.int64(3), np.int64(0), np.int64(1), np.int64(1), np.int64(1), np.int64(2), np.int64(1), np.int64(2), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(2), np.int64(2), np.int64(3), np.int64(3), np.int64(1), np.int64(2), np.int64(2), np.int64(3), np.int64(2), np.int64(2), np.int64(2), np.int64(2), np.int64(1), np.int64(3), np.int64(0), np.int64(1), np.int64(0), np.int64(2), np.int64(1), np.int64(1), np.int64(1), np.int64(2), np.int64(2), np.int64(0), np.int64(1), np.int64(0), np.int64(0), np.int64(2), np.int64(1), np.int64(2), np.int64(2), np.int64(3), np.int64(1), np.int64(2), np.int64(1), np.int64(0), np.int64(2), np.int64(2)]

# %% [markdown]
# ## b pt 큰 순서대로 두 세개 보기

# %%
from importlib import import_module
import os
import sys
import argparse
import linecache
import uproot
import vector
import math
import numpy as np
import matplotlib.pyplot as plt
import awkward as ak

sample = "/data6/Users/snuintern1/LRSM_tb_channel/SAMPLEPRODUCTION/WRtoNMutoMuMuTB-HadTop_MWR-5000_MN-2500_13p6TeV/Run3Summer22NanoAODv12_WRtoNMutoMuMuTB-HadTop_MWR-5000_MN-2500_13p6TeV_1.root"
file = uproot.open(sample)
events = file["Events"]
keys = events.keys()


lhe_pdgid = events["LHEPart_pdgId"].array()
lhe_pt = events["LHEPart_pt"].array()
lhe_eta = events["LHEPart_eta"].array()
lhe_phi = events["LHEPart_phi"].array()
lhe_mass = events["LHEPart_mass"].array()
lhe_status = events["LHEPart_status"].array()

ak4_eta = events["Jet_eta"].array()
ak4_phi = events["Jet_phi"].array()
ak4_mass = events["Jet_pt"].array()
ak4_flavor = events["Jet_hadronFlavour"].array()
ak4_mass = events["Jet_mass"].array()
btag = events["Jet_btagPNetB"].array()

## Fatjet 
fatjet_pt = events["FatJet_pt"].array()
fatjet_eta = events["FatJet_eta"].array()
fatjet_phi = events["FatJet_phi"].array()
fatjet_mass = events["FatJet_mass"].array()

gen_pdgid = events["GenPart_pdgId"].array()
gen_pt = events["GenPart_pt"].array()
gen_eta = events["GenPart_eta"].array()
gen_phi = events["GenPart_phi"].array()

gen_topmask = (gen_pdgid == 6) | (gen_pdgid == -6)
gen_top_eta = gen_eta[gen_topmask]
gen_top_phi = gen_phi[gen_topmask]

ak4_leading_eta = ak4_eta[:, 0]  # Leading jet eta
ak4_leading_phi = ak4_phi[:, 0]  # Leading jet phi
ak4_subleading_eta = ak4_eta[:, 1]  # Subleading jet eta
ak4_subleading_phi = ak4_phi[:, 1]  # Subleading jet phi



lhe_bmask = ((lhe_pdgid == 5) | (lhe_pdgid == -5))  # Bottom quark pdgid mask
gen_bmask = ((gen_pdgid == 5) | (gen_pdgid == -5))  # Bottom quark pdgid mask
flavor_mask = (ak4_flavor== 5) 
print(gen_pt[gen_bmask])
print(lhe_pt[bmask])
print(ak4_pt)
print(ak4_pt[flavor_mask])


delta_phi = ak4_leading_phi - gen_top_phi[:,0]  # Leading jet phi - Top eta
delta_phi = (delta_phi + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
delta_eta = ak4_leading_eta - ak4_subleading_eta  # Leading jet eta - Top eta

delta_phi_subleading = ak4_subleading_phi - gen_top_phi[:,0]  # Subleading jet phi - Top eta
delta_phi_subleading = (delta_phi_subleading + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
delta_eta_subleading = ak4_subleading_eta - gen_top_eta[:,0]  # Subleading jet eta - Top eta
dr_leading = np.sqrt(delta_eta**2 - delta_phi**2)
dr_subleading = np.sqrt(delta_eta_subleading**2 + delta_phi_subleading**2)

#plt.hist(dr_leading, bins=100, range=(0, 3), histtype='step', label='Leading Jet ΔR')
#plt.hist(dr_subleading, bins=100, range=(0, 3), histtype='step', label='Subleading Jet ΔR')
plt.legend()
'''
lhe_eta = lhe_eta[lhe_bmask]
lhe_phi = lhe_phi[lhe_bmask]
lhe_eta = lhe_eta[:, 1]
lhe_phi = lhe_phi[:, 1]
## checking the delta R between leading jet and bottom quark
delta_eta_b = ak4_leading_eta - lhe_eta  # Leading jet eta - Bottom eta
delta_phi_b = ak4_leading_phi - lhe_phi  # Leading jet phi - Bottom
delta_phi_b = (delta_phi_b + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
dr_b = np.sqrt(delta_eta_b**2 + delta_phi_b**2)
plt.hist(dr_b, bins=100, range=(0, 5), histtype='step', label='Leading Jet ΔR with Bottom Quark')
plt.xlabel('ΔR')
'''
ak4_leading_pt = ak4_pt[:, 0]  # Leading jet pt
ak4_subleading_pt = ak4_pt[:, 1]  # Subleading jet pt
check_flavor = ak4_flavor[:, 0]  # Leading jet flavor
check_sub_flavor = ak4_flavor[:, 1]  # Subleading jet flavor
#plt.hist(check_flavor, bins=100, range=(0, 5), histtype='step', label='Leading Jet Flavor')
#plt.hist(check_sub_flavor, bins=100, range=(0, 5), histtype='step', label='Subleading Jet Flavor')
#ratio = ak4_leading_pt - ak4_subleading_pt  # Ratio of leading to subleading jet pt
#plt.hist(ratio, bins=100, range=(-1000, 1000), histtype='step', label='Leading/Subleading Jet PT Ratio')
## 반드시 먼저온게 pt가 큰거 확인 


plt.hist(ak4_leading_pt, bins=100, range=(0, 2000), histtype='step', label='Leading Jet PT')
plt.hist(ak4_subleading_pt, bins=100, range=(0, 2000), histtype='step', label='Subleading Jet PT')

plt.legend()
#plt.xlabel('Jet PT (GeV)')
# Out:
# [[1.14e+03, 80.5, 1.1e+03, 80.5], [...], ..., [210, 393, 22.3, 71.5, 64.8, 393]]
# [[80.5, 1.14e+03], [969, 972], [324, 137], ..., [...], [585, 480], [408, 207]]
# [[1.59e+03, 1.18e+03, 1.16e+03, 101, 25.3], ..., [1.1e+03, 838, ..., 15.6]]
# [[1.16e+03], [1.34e+03, 926], [...], ..., [1.39e+03, 513], [1.1e+03, 89.5, 81]]
# /tmp/ipykernel_2123738/903705360.py:76: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ### AK4 어떻게 b AK4 찾을 건지

# %%
from importlib import import_module
import os
import sys
import argparse
import linecache
import uproot
import vector
import math
import numpy as np
import matplotlib.pyplot as plt
import awkward as ak

sample = "/data6/Users/snuintern1/LRSM_tb_channel/SAMPLEPRODUCTION/WRtoNMutoMuMuTB-HadTop_MWR-5000_MN-4900_13p6TeV/Run3Summer22NanoAODv12_WRtoNMutoMuMuTB-HadTop_MWR-5000_MN-4900_13p6TeV_1.root"
file = uproot.open(sample)
events = file["Events"]
keys = events.keys()


lhe_pdgid = events["LHEPart_pdgId"].array()
lhe_pt = events["LHEPart_pt"].array()
lhe_eta = events["LHEPart_eta"].array()
lhe_phi = events["LHEPart_phi"].array()
lhe_mass = events["LHEPart_mass"].array()
lhe_status = events["LHEPart_status"].array()

ak4_eta = events["Jet_eta"].array()
ak4_phi = events["Jet_phi"].array()
ak4_pt = events["Jet_pt"].array()
ak4_flavor = events["Jet_hadronFlavour"].array()
ak4_mass = events["Jet_mass"].array()
btag = events["Jet_btagPNetB"].array()

## Fatjet 
fatjet_pt = events["FatJet_pt"].array()
fatjet_eta = events["FatJet_eta"].array()
fatjet_phi = events["FatJet_phi"].array()
fatjet_mass = events["FatJet_mass"].array()

gen_pdgid = events["GenPart_pdgId"].array()
gen_pt = events["GenPart_pt"].array()
gen_eta = events["GenPart_eta"].array()
gen_phi = events["GenPart_phi"].array()

def delta_phi(phi1, phi2):
    d = phi1 - phi2
    # wrap to [-π, +π]
    return (d + np.pi) % (2*np.pi) - np.pi

def delta_r(eta1, phi1, eta2, phi2):
    d_eta = eta1 - eta2
    d_phi = delta_phi(phi1, phi2)
    return np.sqrt(d_eta**2 + d_phi**2)

# mask 
bottom_mask = (lhe_pdgid == 5) | (lhe_pdgid == -5)
bottom_eta = lhe_eta[bottom_mask]
bottom_phi = lhe_phi[bottom_mask]
bottom_pt = lhe_pt[bottom_mask]
bottom_mass = lhe_mass[bottom_mask]

topmask = (gen_pdgid == 6) | (gen_pdgid == -6)
top_eta = gen_eta[topmask]
top_phi1 = gen_phi[topmask]

bottompt = bottom_pt[:, 1]#bottom quark 1 = WR* mother
bottometa = bottom_eta[:, 1]
bottomphi = bottom_phi[:, 1]
bottommass = bottom_mass[:, 1]

muon_mask = (lhe_pdgid == 13) | (lhe_pdgid == -13)
muon_pt = lhe_pt[muon_mask]
muon_eta = lhe_eta[muon_mask]
muon_phi = lhe_phi[muon_mask]
muon_mass = lhe_mass[muon_mask]

n_mother_muon_mass = muon_mass[:,0] # muon 1 = WR* mother
n_mother_muon_pt = muon_pt[:,0] # muon 1 = WR* mother
n_mother_muon_eta = muon_eta[:,0]
n_mother_muon_phi = muon_phi[:,0]

WR_mother_muon_mass = muon_mass[:,1] # muon 2 = WR* mother
WR_mother_muon_pt = muon_pt[:,1] # muon 2 = WR* mother
WR_mother_muon_eta = muon_eta[:,1]
WR_mother_muon_phi = muon_phi[:,1]  
'''
## 1. b score 

bscore = []
a_bscore = []
a_btag_scores = []
for i in range(len(bottompt)):
        if (len(ak4_pt[i]) == 0) or ((bottompt[i]) == False) or (len(top_eta[i]) < 2):
            continue
        delta_eta = bottometa[i] - ak4_eta[i]
        delta_phi = bottomphi[i] - ak4_phi[i] 
        delta_phi = (delta_phi + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
        dr = np.sqrt(delta_eta**2 + delta_phi**2)

        if len(dr) == 0: 
            continue
        idx = np.argsort(dr)[0] ## bottom과 제일 가까운 ak4 jet
        if dr[idx] > 0.4: 
            continue
        btag_score = btag[i][idx]
        bscore.append(btag_score)
        
        mask_flavor = ((ak4_flavor[i] == 5) )# Bottom quark flavor mask
        a_btag_score = btag[i]
        a_btag_score = a_btag_score[mask_flavor]
        a_btag_scores.append(a_btag_score)
        if mask_flavor[idx] == True:  # Check if the jet is a bottom quark
            a_bscore.append(btag_score)
btag_score = ak.flatten(btag)

a_btag_scores = ak.flatten(a_btag_scores)
#plt.hist(btag_score, bins=100, range=(0, 1), histtype='step', label='all BTag Score')
plt.hist(bscore, bins=100, range=(0, 1), histtype='step', label='signal BTag Score')
plt.hist(a_btag_scores, bins=100, range=(0, 1), histtype='step', label='masked all BTag Score')
plt.hist(a_bscore, bins=100, range=(0, 1), histtype='step', label='masked signal BTag Score')
plt.legend()
print("all b tag score ", len(btag_score)) ## 500개 중에서 몇개 사용 가능한지 ( 0.4 이내에 있는 것 )
print("signal Btag score", len(bscore)) ## 500개 중에서 몇개 사용 가능한지 (0.4 이내에 있는 것 )
print("masked all b tag score", len(a_btag_scores)) ## 500개 중에서 몇개 사용 가능한지 ( 0.4 이내에 있는 것 )
print("masked signal B tag score", len(a_bscore)) ## 500개 중에서 몇개 사용 가능한지 (0.4 이내에 있는 것 )

#print(f"Number of BTag Scores: {len(bscore)}")
#print(bscore)

## 2. pt. 
pt_list_sig_ak4 = []
a_pt_list_sig_ak4 = [] # after masking signals 
a_all_ak4_pt = [] #after masking all ak4 jets
for i in range(len(bottompt)):
        if (len(ak4_pt[i]) == 0) or ((bottompt[i]) == False) or (len(top_eta[i]) < 2):
            continue
        delta_eta = bottometa[i] - ak4_eta[i]
        delta_phi = bottomphi[i] - ak4_phi[i] 
        delta_phi = (delta_phi + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
        dr = np.sqrt(delta_eta**2 + delta_phi**2)

        delta_eta = bottometa[i] - ak4_eta[i]
        delta_phi = bottomphi[i] - ak4_phi[i] 
        delta_phi = (delta_phi + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
        dr = np.sqrt(delta_eta**2 + delta_phi**2)

        top_etas = top_eta[i][0]
        top_phi = top_phi1[i][0]
        delta_etas = fatjet_eta[i] - top_etas
        delta_phis = fatjet_phi[i] -top_phi 
        delta_phis = (delta_phis + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
        dr_jet = np.sqrt(delta_etas**2 + delta_phis**2)

        if len(dr) == 0: 
            continue
        idx = np.argsort(dr)[0] ## bottom과 제일 가까운 ak4 jet
        if dr[idx] > 0.4: 
            continue
        pt_list_sig_ak4.append(ak4_pt[i][idx])


        delta_eta_ak4_ak8 = fatjet_eta[i][idx_ak8] - ak4_eta[i][idx]
        delta_phi_ak4_ak8 = fatjet_phi[i][idx_ak8] - ak4_phi[i][idx]
        delta_phi_ak4_ak8 = (delta_phi_ak4_ak8 + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
        dr_ak4_ak8 = np.sqrt(delta_eta_ak4_ak8**2 + delta_phi_ak4_ak8**2)
        drs_ak4_ak8.append(dr_ak4_ak8)
        
        if dr_ak4_ak8 > 1.0: ## delta r mask cut 
            continue

        mask_flavor = ((ak4_flavor[i] == 5) )# Bottom quark flavor mask
        a_all_ak4pt = ak4_pt[i]
        a_all_ak4pt = a_all_ak4pt[mask_flavor]
        a_all_ak4_pt.append(a_all_ak4pt) ## masked all ak4 pt


        if mask_flavor[idx] == True:
            a_pt_list_sig_ak4.append(ak4_pt[i][idx]) ## masked signal ak4 pt



all_ak4_pt = ak.flatten(ak4_pt)
a_all_ak4_pt = ak.flatten(a_all_ak4_pt)
plt.hist(pt_list_sig_ak4, bins=30, range=(0, 3000), histtype='step', label='Signal AK4 Jet PT')
plt.hist(a_pt_list_sig_ak4, bins=30, range=(0, 3000), histtype='step', label='Masked Signal AK4 Jet PT')
#plt.hist(all_ak4_pt, bins=100, range=(0, 3000), histtype='step', label='All AK4 Jet PT')
plt.hist(a_all_ak4_pt, bins=30, range=(0, 3000), histtype='step', label='Masked All AK4 Jet PT')
plt.xlabel('Jet PT (GeV)')
#plt.hist(pt_list_sig_ak4, bins=100, range=(0, 3000), histtype='step', label='AK4 Jet PT')
#plt.hist(all_ak4_pt, bins=100, range=(0, 3000), histtype='step', label='All AK4 Jet PT')
plt.legend()
print("signal ak4 pt", len(pt_list_sig_ak4)) ## 500개 중에서 몇개 사용 가능한지 ( 0.4 이내에 있는 것 )
print("masked signal ak4 pt", len(a_pt_list_sig_ak4)) ## 500개 중에서 몇개 사용 가능한지 ( 0.4 이내에 있는 것
print("all ak4 pt", len(all_ak4_pt)) ## 500개 중에서 몇개 사용 가능한지 ( 0.4 이내에 있는 것 )
print("masked all ak4 pt", len(a_all_ak4_pt)) ## 500개 중에서 몇개 사용 가능한지 ( 0.4 이내에 있는 것 )

## 3. ΔR between AK4 jet and AK8 jet 

drs_ak4_ak8 = []
drs_all_ak4_ak8 = []
a_drs_ak4_ak8 = [] # after masking signals
a_drs_all_ak4_ak8 = [] # after masking all ak4 jets
for i in range(len(bottompt)):
        if (len(ak4_pt[i]) == 0) or ((bottompt[i]) == False) or (len(top_eta[i]) < 2):
            continue
        delta_eta = bottometa[i] - ak4_eta[i]
        delta_phi = bottomphi[i] - ak4_phi[i] 
        delta_phi = (delta_phi + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
        dr = np.sqrt(delta_eta**2 + delta_phi**2)

        top_etas = top_eta[i][0]
        top_phi = top_phi1[i][0]
        delta_etas = fatjet_eta[i] - top_etas
        delta_phis = fatjet_phi[i] -top_phi 
        delta_phis = (delta_phis + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
        dr_jet = np.sqrt(delta_etas**2 + delta_phis**2)

        if len(dr) == 0: 
            continue
        idx = np.argsort(dr)[0] ## bottom과 제일 가까운 ak4 jet
        idx_ak8 = np.argsort(dr_jet)[0] ## top 과 제일 가까운 fatjet
        if dr[idx] > 0.4: 
            continue

        delta_eta_ak4_ak8 = fatjet_eta[i][idx_ak8] - ak4_eta[i][idx]
        delta_phi_ak4_ak8 = fatjet_phi[i][idx_ak8] - ak4_phi[i][idx]
        delta_phi_ak4_ak8 = (delta_phi_ak4_ak8 + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
        dr_ak4_ak8 = np.sqrt(delta_eta_ak4_ak8**2 + delta_phi_ak4_ak8**2)
        drs_ak4_ak8.append(dr_ak4_ak8)

        delta_eta_all_ak4_ak8 = fatjet_eta[i][idx_ak8] - ak4_eta[i]
        delta_phi_all_ak4_ak8 = fatjet_phi[i][idx_ak8] - ak4_phi[i]
        delta_phi_all_ak4_ak8 = (delta_phi_all_ak4_ak8 + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
        dr_all_ak4_ak8 = np.sqrt(delta_eta_all_ak4_ak8**2 + delta_phi_all_ak4_ak8**2)
        drs_all_ak4_ak8.append(dr_all_ak4_ak8)
        
        mask_flavor = ((ak4_flavor[i] == 5) )# Bottom quark flavor mask
        a_drs_all_ak4_ak8.append(dr_all_ak4_ak8[mask_flavor]) ## masked all ak4 dr
        if mask_flavor[idx] == True:
            a_drs_ak4_ak8.append(dr_ak4_ak8)

drs_all_ak4_ak8 = ak.flatten(drs_all_ak4_ak8)
a_drs_all_ak4_ak8 = ak.flatten(a_drs_all_ak4_ak8)
#plt.hist(drs_all_ak4_ak8, bins=100, range=(0, 5), histtype='step', label='ΔR between All AK4 and AK8 Jet')
plt.hist(a_drs_all_ak4_ak8, bins=100, range=(0, 5), histtype='step', label='Masked ΔR between All AK4 and AK8 Jet')
plt.hist(drs_ak4_ak8, bins=100, range=(0, 5), histtype='step', label='ΔR between Closest AK4 and AK8 Jet')
plt.hist(a_drs_ak4_ak8, bins=100, range=(0, 5), histtype='step', label='Masked ΔR between Closest AK4 and AK8 Jet')
plt.xlabel('ΔR between AK4 and AK8 Jet')
#plt.hist(drs_all_ak4_ak8, bins=100, range=(0, 5), histtype='step', label='ΔR between AK4 and AK8 Jet')
#plt.hist(drs_ak4_ak8, bins=100, range=(0, 5), histtype='step', label='ΔR between Closest AK4 and AK8 Jet')
plt.legend()        


## 4. flavor 
flavor_ak4 = []

for i in range(len(bottompt)):
        if (len(ak4_pt[i]) == 0) or ((bottompt[i]) == False) or (len(top_eta[i]) < 2):
            continue
        delta_eta = bottometa[i] - ak4_eta[i]
        delta_phi = bottomphi[i] - ak4_phi[i] 
        delta_phi = (delta_phi + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
        dr = np.sqrt(delta_eta**2 + delta_phi**2)

        top_etas = top_eta[i][0]
        top_phi = top_phi1[i][0]
        delta_etas = fatjet_eta[i] - top_etas
        delta_phis = fatjet_phi[i] -top_phi 
        delta_phis = (delta_phis + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
        dr_jet = np.sqrt(delta_etas**2 + delta_phis**2)

        if len(dr) == 0: 
            continue
        idx = np.argsort(dr)[0] ## bottom과 제일 가까운 ak4 jet
        if dr[idx] > 0.4: 
            continue
        flavor = ak4_flavor[i][idx]
        flavor_ak4.append(flavor)

ak4_flavor = ak.flatten(ak4_flavor)
plt.hist(flavor_ak4, bins=100, range=(-5, 5), histtype='step', label='AK4 Jet Flavor')
plt.hist(ak4_flavor, bins=100, range=(-5, 5), histtype='step', label='All AK4 Jet Flavor')
plt.legend()
flavor_ak4_num = np.sum(np.array(ak4_flavor) ) ## b jet
print(f"Number of b jets in AK4: {flavor_ak4_num}")


### 가장 효과적인건 mask flavor , b score , pt , ΔR between AK4 and AK8 jet 에 얼마나 영향 주는 지 확인 하기 
mask_flavor = (ak4_flavor == 5) | (ak4_flavor == -5)  # Bottom quark flavor mask

## before mask
bscore = []
pt_list_sig_ak4 = []
drs_ak4_ak8 = []
drs_all_ak4_ak8 = []
# after mask
a_bscore = []
a_pt_list_sig_ak4 = []
a_drs_ak4_ak8 = []
a_drs_all_ak4_ak8 = []
for i in range(len(bottompt)):
        if (len(ak4_pt[i]) == 0) or ((bottompt[i]) == False) or (len(top_eta[i]) < 2):
            continue
        delta_eta = bottometa[i] - ak4_eta[i]
        delta_phi = bottomphi[i] - ak4_phi[i] 
        delta_phi = (delta_phi + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
        dr = np.sqrt(delta_eta**2 + delta_phi**2)

        top_etas = top_eta[i][0]
        top_phi = top_phi1[i][0]
        delta_etas = fatjet_eta[i] - top_etas
        delta_phis = fatjet_phi[i] -top_phi 
        delta_phis = (delta_phis + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
        dr_jet = np.sqrt(delta_etas**2 + delta_phis**2)


        if len(dr) == 0: 
            continue
        idx = np.argsort(dr)[0] ## bottom과 제일 가까운 ak4 jet
        idx_ak8 = np.argsort(dr_jet)[0] ## top 과 제일 가까운 fatjet
        if dr[idx] > 0.4: 
            continue
        btag_score = btag[i][idx] ## bscore
        bscore.append(btag_score)
        
        pt_list_sig_ak4.append(ak4_pt[i][idx])
        
        delta_eta_ak4_ak8 = fatjet_eta[i][idx_ak8] - ak4_eta[i][idx]
        delta_phi_ak4_ak8 = fatjet_phi[i][idx_ak8] - ak4_phi[i][idx]
        delta_phi_ak4_ak8 = (delta_phi_ak4_ak8 + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
        dr_ak4_ak8 = np.sqrt(delta_eta_ak4_ak8**2 + delta_phi_ak4_ak8**2)
        drs_ak4_ak8.append(dr_ak4_ak8)

        delta_eta_all_ak4_ak8 = fatjet_eta[i][idx_ak8] - ak4_eta[i]
        delta_phi_all_ak4_ak8 = fatjet_phi[i][idx_ak8] - ak4_phi[i]
        delta_phi_all_ak4_ak8 = (delta_phi_all_ak4_ak8 + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
        dr_all_ak4_ak8 = np.sqrt(delta_eta_all_ak4_ak8**2 + delta_phi_all_ak4_ak8**2)
        drs_all_awk4_ak8.append(dr_all_ak4_ak8)
        if not mask_flavor[[i][idx]]:  # Check if the jet is a bottom quark
            continue
        btag_score = btag[i][idx] ## bscore
        a_bscore.append(btag_score)
        
        a_pt_list_sig_ak4.append(ak4_pt[i][idx])
        
        delta_eta_ak4_ak8 = fatjet_eta[i][idx_ak8] - ak4_eta[i][idx]
        delta_phi_ak4_ak8 = fatjet_phi[i][idx_ak8] - ak4_phi[i][idx]
        delta_phi_ak4_ak8 = (delta_phi_ak4_ak8 + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
        dr_ak4_ak8 = np.sqrt(delta_eta_ak4_ak8**2 + delta_phi_ak4_ak8**2)
        a_drs_ak4_ak8.append(dr_ak4_ak8)

        delta_eta_all_ak4_ak8 = fatjet_eta[i][idx_ak8] - ak4_eta[i]
        delta_phi_all_ak4_ak8 = fatjet_phi[i][idx_ak8] - ak4_phi[i]
        delta_phi_all_ak4_ak8 = (delta_phi_all_ak4_ak8 + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
        dr_all_ak4_ak8 = np.sqrt(delta_eta_all_ak4_ak8**2 + delta_phi_all_ak4_ak8**2)
        a_drs_all_ak4_ak8.append(dr_all_ak4_ak8)

drs_all_ak4_ak8 = ak.flatten(drs_all_ak4_ak8)
a_drs_all_ak4_ak8 = ak.flatten(a_drs_all_ak4_ak8)
all_ak4_pt = ak.flatten(ak4_pt)
a_all_ak4_pt = ak.flatten(a_pt_list_sig_ak4)

fig , axs = plt.subplots(4, 3 , figsize=(10, 20))
axs[0,0].hist(drs_all_ak4_ak8, bins=100, range=(0, 5), histtype='step', label='ΔR between AK4 and AK8 Jet')
axs[0,0].hist(drs_ak4_ak8, bins=100, range=(0, 5), histtype='step', label='ΔR between Closest AK4 and AK8 Jet')
axs[0,0].hist(a_drs_all_ak4_ak8, bins=100, range=(0, 5), histtype='step', label='ΔR between AK4 and AK8 Jet after Mask')
axs[0,0].hist(a_drs_ak4_ak8, bins=100, range=(0, 5), histtype='step', label='ΔR between Closest AK4 and AK8 Jet after Mask')
axs[0,0].set_xlabel('ΔR')
axs[0,0].set_ylabel('Number of Jets')

axs[1,0].hist(bscore, bins=100, range=(0, 1), histtype='step', label='BTag Score')
axs[1,0].hist()
axs[1,0].hist(a_bscore, bins=100, range=(0, 1), histtype='step', label='BTag Score after Mask')

'''
## 4.mass
mass_list_sig_ak4 = []
a_mass_list_sig_ak4 = [] # after masking signals 
a_all_ak4_mass = [] #after masking all ak4 jets
for i in range(len(bottompt)):
        if (len(ak4_pt[i]) == 0) or ((bottompt[i]) == False) or (len(top_eta[i]) < 2):
            continue
        delta_eta = bottometa[i] - ak4_eta[i]
        delta_phi = bottomphi[i] - ak4_phi[i] 
        delta_phi = (delta_phi + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
        dr = np.sqrt(delta_eta**2 + delta_phi**2)

        delta_eta = bottometa[i] - ak4_eta[i]
        delta_phi = bottomphi[i] - ak4_phi[i] 
        delta_phi = (delta_phi + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
        dr = np.sqrt(delta_eta**2 + delta_phi**2)

        top_etas = top_eta[i][0]
        top_phi = top_phi1[i][0]
        delta_etas = fatjet_eta[i] - top_etas
        delta_phis = fatjet_phi[i] -top_phi 
        delta_phis = (delta_phis + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
        dr_jet = np.sqrt(delta_etas**2 + delta_phis**2)

        if len(dr) == 0: 
            continue
        idx = np.argsort(dr)[0] ## bottom과 제일 가까운 ak4 jet
        #if dr[idx] > 0.4: 
        #    continue
        mass_list_sig_ak4.append(ak4_mass[i][idx])


        delta_eta_ak4_ak8 = fatjet_eta[i][idx_ak8] - ak4_eta[i][idx]
        delta_phi_ak4_ak8 = fatjet_phi[i][idx_ak8] - ak4_phi[i][idx]
        delta_phi_ak4_ak8 = (delta_phi_ak4_ak8 + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
        dr_ak4_ak8 = np.sqrt(delta_eta_ak4_ak8**2 + delta_phi_ak4_ak8**2)
        drs_ak4_ak8.append(dr_ak4_ak8)
        
        #if dr_ak4_ak8 > 1.0: ## delta r mask cut 
        #    continue
        if ak4_mass[i][idx] <30 or ak4_mass[i][idx] > 130: ## mass cut
            continue
        mask_flavor = ((ak4_flavor[i] == 5) )# Bottom quark flavor mask
        mask_mass_flavor = (ak4_flavor[i] == 5) & (ak4_mass[i] > 30) & (ak4_mass[i] < 130) # Bottom quark flavor mask and mass cut
        a_all_ak4mass = ak4_mass[i]
        a_all_ak4mass = a_all_ak4mass[mask_mass_flavor]
        a_all_ak4_mass.append(a_all_ak4mass) ## masked all ak4 pt


        if mask_flavor[idx] == True:
            a_mass_list_sig_ak4.append(ak4_mass[i][idx]) ## masked signal ak4 pt



all_ak4_mass = ak.flatten(ak4_mass)
a_all_ak4_mass = ak.flatten(a_all_ak4_mass)
plt.hist(mass_list_sig_ak4, bins=50, range=(0, 300), histtype='step', label='Signal AK4 Jet mass')
plt.hist(a_mass_list_sig_ak4, bins=50, range=(0, 300), histtype='step', label='Masked Signal AK4 Jet mass')
#plt.hist(all_ak4_mass, bins=50, range=(0, 500), histtype='step', label='All AK4 Jet mass')
plt.hist(a_all_ak4_mass, bins=50, range=(0, 300), histtype='step', label='Masked All AK4 Jet mass')
plt.xlabel('Jet mass (GeV)')

plt.legend()
print("signal ak4 pt", len(mass_list_sig_ak4)) ## 500개 중에서 몇개 사용 가능한지 ( 0.4 이내에 있는 것 )
print("masked signal ak4 pt", len(a_mass_list_sig_ak4)) ## 500개 중에서 몇개 사용 가능한지 ( 0.4 이내에 있는 것
print("all ak4 pt", len(all_ak4_mass)) ## 500개 중에서 몇개 사용 가능한지 ( 0.4 이내에 있는 것 )
print("masked all ak4 pt", len(a_all_ak4_mass)) ## 500개 중에서 몇개 사용 가능한지 ( 0.4 이내에 있는 것 )
# Out:
# signal ak4 pt 499
# masked signal ak4 pt 355
# all ak4 pt 3815
# masked all ak4 pt 415

# %% [markdown]
# ### mass , flavor 사용 불가능 -> btag score (b jet 구분 ), delta r(top jet 주변 거는 안 쓰기 ) ,  그 다음 pt 보자

# %%
from importlib import import_module
import os
import sys
import argparse
import linecache
import uproot
import vector
import math
import numpy as np
import matplotlib.pyplot as plt
import awkward as ak

sample = "/data6/Users/achihwan/LRSM_tb_channel/SAMPLEPRODUCTION/WRtoNMutoMuMuTB-HadTop_MWR-5000_MN-2500_13p6TeV/Run3Summer22NanoAODv12_WRtoNMutoMuMuTB-HadTop_MWR-5000_MN-2500_13p6TeV_1.root"
file = uproot.open(sample)
events = file["Events"]
keys = events.keys()


lhe_pdgid = events["LHEPart_pdgId"].array()
lhe_pt = events["LHEPart_pt"].array()
lhe_eta = events["LHEPart_eta"].array()
lhe_phi = events["LHEPart_phi"].array()
lhe_mass = events["LHEPart_mass"].array()
lhe_status = events["LHEPart_status"].array()

ak4_eta = events["Jet_eta"].array()
ak4_phi = events["Jet_phi"].array()
ak4_pt = events["Jet_pt"].array()
ak4_mass = events["Jet_mass"].array()
btag = events["Jet_btagPNetB"].array()

## Fatjet 
fatjet_pt = events["FatJet_pt"].array()
fatjet_eta = events["FatJet_eta"].array()
fatjet_phi = events["FatJet_phi"].array()
fatjet_mass = events["FatJet_mass"].array()

gen_pdgid = events["GenPart_pdgId"].array()
gen_pt = events["GenPart_pt"].array()
gen_eta = events["GenPart_eta"].array()
gen_phi = events["GenPart_phi"].array()

def delta_phi(phi1, phi2):
    d = phi1 - phi2
    # wrap to [-π, +π]
    return (d + np.pi) % (2*np.pi) - np.pi

def delta_r(eta1, phi1, eta2, phi2):
    d_eta = eta1 - eta2
    d_phi = delta_phi(phi1, phi2)
    return np.sqrt(d_eta**2 + d_phi**2)

# mask 
bottom_mask = (lhe_pdgid == 5) | (lhe_pdgid == -5)
bottom_eta = lhe_eta[bottom_mask]
bottom_phi = lhe_phi[bottom_mask]
bottom_pt = lhe_pt[bottom_mask]
bottom_mass = lhe_mass[bottom_mask]

topmask = (gen_pdgid == 6) | (gen_pdgid == -6)
top_eta = gen_eta[topmask]
top_phi1 = gen_phi[topmask]

bottompt = bottom_pt[:, 1]#bottom quark 1 = WR* mother
bottometa = bottom_eta[:, 1]
bottomphi = bottom_phi[:, 1]
bottommass = bottom_mass[:, 1]

muon_mask = (lhe_pdgid == 13) | (lhe_pdgid == -13)
muon_pt = lhe_pt[muon_mask]
muon_eta = lhe_eta[muon_mask]
muon_phi = lhe_phi[muon_mask]
muon_mass = lhe_mass[muon_mask]

n_mother_muon_mass = muon_mass[:,0] # muon 1 = WR* mother
n_mother_muon_pt = muon_pt[:,0] # muon 1 = WR* mother
n_mother_muon_eta = muon_eta[:,0]
n_mother_muon_phi = muon_phi[:,0]

WR_mother_muon_mass = muon_mass[:,1] # muon 2 = WR* mother
WR_mother_muon_pt = muon_pt[:,1] # muon 2 = WR* mother
WR_mother_muon_eta = muon_eta[:,1]
WR_mother_muon_phi = muon_phi[:,1]  

bscore = []
a_btag_scores = []
idx_ak8s = []
bover08dr = []
drs_all_ak4_ak8 =[]

bover08pt = []

all_bover08pt = []

bover08ptdrover10_pt = []
for i in range(len(bottompt)):
        if (len(ak4_pt[i]) == 0) or ((bottompt[i]) == False) or (len(top_eta[i]) < 2):
            continue
        delta_eta = bottometa[i] - ak4_eta[i]
        delta_phi = bottomphi[i] - ak4_phi[i] 
        delta_phi = (delta_phi + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
        dr = np.sqrt(delta_eta**2 + delta_phi**2)
        
        top_etas = top_eta[i][0]
        top_phi = top_phi1[i][0]
        delta_etas = fatjet_eta[i] - top_etas
        delta_phis = fatjet_phi[i] -top_phi 
        delta_phis = (delta_phis + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
        dr_jet = np.sqrt(delta_etas**2 + delta_phis**2)

        


        if ((len(dr) >0 ) and len(dr_jet) > 0):
            idx_ak8 = np.argsort(dr_jet)[0] ## top 과 제일 가까운 fatjet
            idx_ak8s.append(idx_ak8)
        else:
            idx_ak8s.append(False)
        
        if len(dr) == 0: 
            continue
        idx = np.argsort(dr)[0] ## bottom과 제일 가까운 ak4 jet
        if dr[idx] > 0.4: 
            continue
        btag_score = btag[i][idx]
        bscore.append(btag_score)
        
        
        a_btag_score = btag[i]
        a_btag_scores.append(a_btag_score)


        ## b 중에서 거리가 제일 가깝고 , 0.8 이상의 score, 의 ak8 과의 거리 찾기 
        btag08_closest = btag[i][idx] 
        if btag08_closest > 0.8:
            delta_eta_ak4_ak8 = fatjet_eta[i][idx_ak8] - ak4_eta[i][idx]
            delta_phi_ak4_ak8 = fatjet_phi[i][idx_ak8] - ak4_phi[i][idx]
            delta_phi_ak4_ak8 = (delta_phi_ak4_ak8 + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
            dr_ak4_ak8 = np.sqrt(delta_eta_ak4_ak8**2 + delta_phi_ak4_ak8**2)
            bover08dr.append(dr_ak4_ak8)
            bover08pt.append(ak4_pt[i][idx])

        ## 모든 ak4와 ak8사이의 거리 찾기
        
        all_btag = btag[i]
        passed_all_btag = all_btag > 0.8 ## 각 이벤트에 0.8 보다 큰 녀석들의 인덱스 
        print(btag[i])
        print(passed_all_btag)
        delta_eta_all_ak4_ak8 = fatjet_eta[i][idx_ak8] - ak4_eta[i][passed_all_btag]
        delta_phi_all_ak4_ak8 = fatjet_phi[i][idx_ak8] - ak4_phi[i][passed_all_btag]
        delta_phi_all_ak4_ak8 = (delta_phi_all_ak4_ak8 + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
        dr_all_ak4_ak8 = np.sqrt(delta_eta_all_ak4_ak8**2 + delta_phi_all_ak4_ak8**2)
        idx_dr_all_ak4_ak8_mask = dr_all_ak4_ak8 > 1.0
        
        if len(dr_all_ak4_ak8) > 0:
            
            drs_all_ak4_ak8.append(dr_all_ak4_ak8)
            all_bover08pt.append(ak4_pt[i][passed_all_btag])
            #idx_dr_all_ak4_ak8_mask = ak.flatten(idx_dr_all_ak4_ak8_mask)
            #print(idx_dr_all_ak4_ak8_mask)
            bover08ptdrover10 = ak4_pt[i][idx_dr_all_ak4_ak8_mask]
            bover08ptdrover10_pt.append(bover08ptdrover10)



all_btag_score = ak.flatten(btag)
a_btag_scores = ak.flatten(a_btag_scores)

plt ,axs = plt.subplots(3, 2, figsize=(10, 10))
axs[0,0].hist(bscore, bins=100, range=(0, 1), histtype='step', label='signal BTag Score')
axs[0,0].hist(all_btag_score, bins=100, range=(0, 1), histtype='step', label='All BTag Score')
axs[0,0].set_xlabel('BTag Score')
axs[0,0].set_ylabel('Number of Jets')
axs[0,0].legend()

axs[0,1].hist(bscore, bins=100, range=(0.8, 1), histtype='step', label='signal BTag Score')
axs[0,1].hist(all_btag_score, bins=100, range=(0.8, 1), histtype='step', label='All BTag Score')
axs[0,1].set_xlabel('BTag Score')
axs[0,1].set_ylabel('Number of Jets')
axs[0,1].legend()
print(len(bscore),"signal btag score")
print(len(all_btag_score),"all btag score")
drs_all_ak4_ak8 = ak.flatten(drs_all_ak4_ak8)
print(len(drs_all_ak4_ak8),"all ak4 ak8 drs")
print(len(bover08dr),"bover08 drs")
axs[1,0].hist(drs_all_ak4_ak8, bins=100, range=(0, 5), histtype='step', label='ΔR between All AK4 and AK8 Jet')
axs[1,0].hist(bover08dr, bins=100, range=(0, 5), histtype='step', label='ΔR between BTag Score > 0.8 and AK8 Jet')
axs[1,0].set_xlabel('ΔR between BTag Score > 0.8 and AK8 Jet')
axs[1,0].set_ylabel('Number of Jets')
axs[1,0].legend()

bover08ptdrover10_pt = ak.flatten(bover08ptdrover10_pt)
all_bover08pt = ak.flatten(all_bover08pt)
axs[1,1].hist(all_bover08pt, bins=100, range=(0, 3000), histtype='step', label='all AK4 Jet PT with BTag Score > 0.8')
#axs[1,1].hist(bover08pt, bins=100, range=(0, 3000), histtype='step', label='AK4 Jet PT with BTag Score > 0.8 and Closest AK8 Jet')
axs[1,1].hist(bover08ptdrover10_pt, bins=100, range=(0, 3000), histtype='step', label='AK4 Jet PT with BTag Score > 0.8 and Closest AK8 Jet after ΔR > 1.0')
axs[1,1].set_xlabel('AK4 Jet PT with BTag Score > 0.8')
axs[1,1].set_ylabel('Number of Jets')   
axs[1,1].legend()



print("all b tag score ", len(all_btag_score)) ## 500개 중에서 몇개 사용 가능한지 ( 0.4 이내에 있는 것 )
print("signal Btag score", len(bscore)) ## 500개 중에서 몇개 사용 가능한지 (0.4 이내에 있는 것 )
print("masked all b tag score", len(a_btag_scores)) ## 500개 중에서 몇개 사용 가능한지 ( 0.4 이내에 있는 것 )


#print(f"Number of BTag Scores: {len(bscore)}")
#print(bscore)
# Out:
# [0.0231, 0.032, 0.486, 0.00793, 0.0189]
# [False, False, False, False, False]
# [0.762, 0.0178, 0.86, 0.0349, 0.00417, 0.0411, 0.00602]
# [False, False, True, False, False, False, False]
# [0.0145, 0.907, 0.0194, 0.985, -1, 0.0219]
# [False, True, False, True, False, False]
# [0.0116, 0.82, 0.997, 0.0356, 0.0108, 0.0336, -1]
# [False, True, True, False, False, False, False]
# [0.026, 0.917, 0.092, 0.901, 0.0489]
# [False, True, False, True, False]
# [0.999, 0.0358, 0.368, 0.00286, -1, 0.00404, 0.0646, 0.0164]
# [True, False, False, False, False, False, False, False]
# [0.00751, 0.0186, 0.0297, 0.999, -1, -1, 0.711, 0.882]
# [False, False, False, True, False, False, False, True]
# [0.0244, 0.346, 0.285, 0.0484]
# [False, False, False, False]
# [0.0145, 0.0091, 0.0261, 0.0164, 0.114, 0.0216, 0.0145]
# [False, False, False, False, False, False, False]
# [0.0417, 0.249, 0.032, -1, 0.997, 0.137, 0.0326, 0.0767]
# [False, False, False, False, True, False, False, False]
# [0.164, 0.0116, 0.0298, 0.387, 0.0564, 0.00338, 0.00361, -1, -1]
# [False, False, False, False, False, False, False, False, False]
# [0.0537, 0.0136, 0.00953, 0.00544, -1, -1, -1, -1, -1]
# [False, False, False, False, False, False, False, False, False]
# [0.129, 0.927, 0.0413, 0.855, 0.00449]
# [False, True, False, True, False]
# [0.0375, 0.0226, 0.782, 0.715, 0.258, 0.0112, 0.0109, 0.548, 0.0184]
# [False, False, False, False, False, False, False, False, False]
# [0.0234, 0.0226, 0.993, 0.99, -1]
# [False, False, True, True, False]
# [0.0363, 0.893, 0.0356, 0.00526, -1, -1]
# [False, True, False, False, False, False]
# [0.0891, 0.992, 0.999, 0.0261, -1]
# [False, True, True, False, False]
# [0.365, 0.0764, 0.0338, 0.878, 0.00264, 0.468]
# [False, False, False, True, False, False]
# [0.0202, 0.0167, 1, 0.996, 0.00544, 0.0231, 0.0242, -1]
# [False, False, True, True, False, False, False, False]
# [0.0338, 0.0294, 0.205, 0.0021, 0.384, ..., 0.00884, 0.00491, 0.997, -1, 0.168]
# [False, False, False, False, False, ..., False, False, True, False, False]
# [0.0192, 0.997, 0.0783, 0.975, 0.0439, 0.0247, 0.0432, 0.0973, 0.0109]
# [False, True, False, True, False, False, False, False, False]
# [0.0352, 0.0332, 0.868, 0.0033, 0.0236, 0.00469, 0.00654, -1]
# [False, False, True, False, False, False, False, False]
# [0.0974, 0.0292, 0.0508, 0.031, 0.148, -1, -1, 0.0123]
# [False, False, False, False, False, False, False, False]
# [0.016, 0.831, 1, 0.0269, 0.0318]
# [False, True, True, False, False]
# [0.0177, 0.333, 0.00983, 0.021, 0.0423, 0.00396, 0.00671, -1]
# [False, False, False, False, False, False, False, False]
# [0.0292, 0.138, 0.0241, 0.396, 0.0057, 0.00682]
# [False, False, False, False, False, False]
# [0.0609, 0.029, 0.0196, 0.661, 0.00914, -1, 0.0726]
# [False, False, False, False, False, False, False]
# [0.0364, 0.519, -1, 0.0304, 0.0851, 0.114, -1]
# [False, False, False, False, False, False, False]
# [0.0617, 0.0537, 0.374, 0.479, 0.00242, 0.0164]
# [False, False, False, False, False, False]
# [0.0282, 0.0511, 0.694, 0.00908, 0.00607, -1, -1]
# [False, False, False, False, False, False, False]
# [0.0251, 0.0687, 0.745, 0.0611, 0.0223, 0.969]
# [False, False, False, False, False, True]
# [0.0399, 0.824, 0.0166, 0.994, -1, 0.0168, -1]
# [False, True, False, True, False, False, False]
# [0.0475, 1, 0.979, 0.0377, 0.0121, 0.0112, 0.00449, -1]
# [False, True, True, False, False, False, False, False]
# [0.0193, 0.993, 0.0254, 0.924, 0.00156, ..., 0.00316, 0.00718, -1, -1, -1]
# [False, True, False, True, False, False, False, False, False, False, False]
# [0.0136, 0.0345, 0.568, 0.519, 0.0572, -1, -1, 0.00984, 0.019]
# [False, False, False, False, False, False, False, False, False]
# [0.0621, 0.0441, 0.519, 0.994, -1]
# [False, False, False, True, False]
# [0.0317, 0.145, 0.553, 0.0297, 0.00337, 0.0235, -1]
# [False, False, False, False, False, False, False]
# [0.024, 0.0394, 0.00974, 0.34, 0.748, 0.00199, 0.0967]
# [False, False, False, False, False, False, False]
# [0.0106, 0.13, 0.022, 0.975, 0.00782, -1, 0.0339, 0.402, -1]
# [False, False, False, True, False, False, False, False, False]
# [0.0246, 0.0308, 0.976, 1, 0.00521, ..., 0.00661, 0.00963, -1, 0.00745, -1]
# [False, False, True, True, False, False, False, False, False, False, False]
# [0.0171, 0.882, 0.0179, 0.978, 0.00358, 0.0173, 0.301]
# [False, True, False, True, False, False, False]
# [0.979, 0.0198, 0.861, 0.0269, -1, -1, 0.00875, 0.0156]
# [True, False, True, False, False, False, False, False]
# [0.0287, 0.902, 0.0225, 0.0101, 0.00231, 0.00762, 0.0623]
# [False, True, False, False, False, False, False]
# [0.0172, 0.0172, 0.299, 0.0158, 0.0117, 0.329]
# [False, False, False, False, False, False]
# [0.0332, 0.0263, 0.995, 0.991, 0.00938, -1, 0.0115, -1]
# [False, False, True, True, False, False, False, False]
# [0.212, 0.0515, 0.0338, 0.00779, 0.00319, 0.682, -1, -1]
# [False, False, False, False, False, False, False, False]
# [0.0319, 0.992, 0.0476, 0.00709, 0.0356]
# [False, True, False, False, False]
# [0.0159, 0.505, 0.0191, 0.0792, 0.00581, 0.00727, -1, 0.145]
# [False, False, False, False, False, False, False, False]
# [0.0271, 0.173, 0.0246, 0.00502, -1]
# [False, False, False, False, False]
# [0.146, 0.958, 0.999, 0.0217, 0.127, ..., -1, 0.0124, 0.0102, 0.00717, 0.17]
# [False, True, True, False, False, False, ..., False, False, False, False, False]
# [0.987, 0.0488, 0.0274, 0.999, 0.00327, 0.00347, 0.0202, 0.145]
# [True, False, False, True, False, False, False, False]
# [0.0453, 0.0411, 0.0341, 0.0601, 0.998, 0.0223, 0.00769]
# [False, False, False, False, True, False, False]
# [0.0227, 0.0065, 0.998, 0.0341, 0.00421, 0.0693, 0.00417, 0.352, 0.0414]
# [False, False, True, False, False, False, False, False, False]
# [0.029, 0.0125, 0.956, 0.899, 0.043, 0.0347, -1, -1]
# [False, False, True, True, False, False, False, False]
# [0.0268, 0.91, 0.999, 0.0214, 0.00576, 0.0058, -1]
# [False, True, True, False, False, False, False]
# [0.0435, 0.913, 0.0345, 0.992, 0.00391, 0.00418, 0.0227]
# [False, True, False, True, False, False, False]
# [0.0517, 0.0326, 0.00459, 0.992, 0.943]
# [False, False, False, True, True]
# [0.0319, 0.603, 0.999, 0.0226, 0.00419, 0.00534, 0.0118]
# [False, False, True, False, False, False, False]
# [0.97, 0.0798, 0.164, 0.997, 0.00264, 0.0176]
# [True, False, False, True, False, False]
# [0.0359, 0.782, 0.0627, 0.995, 0.00378, 0.00583, 0.00409, 0.0057, -1, -1]
# [False, False, False, True, False, False, False, False, False, False]
# [0.992, 0.0391, 0.0509, 0.0356, 0.00339, -1, 0.0693, 0.0219, 0.00854]
# [True, False, False, False, False, False, False, False, False]
# [0.0755, 0.965, 0.027, 0.00267, 0.00573, 0.0657, -1, 0.0185, 0.0782, -1]
# [False, True, False, False, False, False, False, False, False, False]
# [0.0177, 0.0278, 0.0193, 0.647, -1, -1, -1, 0.018, 0.0183, 0.00791]
# [False, False, False, False, False, False, False, False, False, False]
# [0.019, 0.597, 0.0281, 0.0475, 0.201, 0.0066]
# [False, False, False, False, False, False]
# [0.0613, 0.068, 0.909, 0.0355, 0.189]
# [False, False, True, False, False]
# [0.0291, 0.0176, 0.521, 0.999, 0.00842, -1]
# [False, False, False, True, False, False]
# [0.0269, 0.0237, 0.946, 0.0532, 0.807, 0.0281, 0.00465]
# [False, False, True, False, True, False, False]
# [0.978, 0.0217, 0.00519, 0.769, 0.00333, 0.00729]
# [True, False, False, False, False, False]
# [0.0322, 0.0555, 0.052, 0.0118, 0.182, 1, 0.0113, 0.0427]
# [False, False, False, False, False, True, False, False]
# [0.0357, 0.0302, 0.996, 0.999, 0.0583, 0.0558]
# [False, False, True, True, False, False]
# [0.024, 0.159, 0.0267, 0.00903, 0.988, 0.0848]
# [False, False, False, False, True, False]
# [0.0251, 0.0781, 0.989, 0.00829, 0.999, 0.156, -1, -1, -1]
# [False, False, True, False, True, False, False, False, False]
# [0.0276, 0.417, 0.0239, 0.883, 0.0269, 0.0159, 0.0637, -1, -1]
# [False, False, False, True, False, False, False, False, False]
# [0.0964, 0.265, 0.0233, 0.999, 0.152, 0.0982, -1]
# [False, False, False, True, False, False, False]
# [0.0825, 0.0353, 0.00953, 0.00678, 0.999, 0.00305, 0.994, 0.0197, 0.00536]
# [False, False, False, False, True, False, True, False, False]
# [0.0206, 0.0229, 0.00729, 0.145, 0.0369, -1, 0.016, 0.254, -1]
# [False, False, False, False, False, False, False, False, False]
# [0.0145, 0.984, 0.0102, 0.187, 0.00888, 0.405, 0.0317]
# [False, True, False, False, False, False, False]
# [0.0381, 0.685, 0.0194, 0.957]
# [False, False, False, True]
# [0.0574, 0.0282, 0.0271, 0.947, 0.0206, 0.0136]
# [False, False, False, True, False, False]
# [0.119, 0.0764, 0.0291, 0.0309, 0.00263, 0.015, 0.028]
# [False, False, False, False, False, False, False]
# [0.0404, 0.234, 0.0267, 0.0126, 0.805, -1, -1]
# [False, False, False, False, True, False, False]
# [0.0225, 0.0374, 0.943, 0.964, 0.00531, 0.0108]
# [False, False, True, True, False, False]
# [0.067, 0.0367, 0.0296, 0.0762, 0.455, ..., 0.0616, 0.0797, -1, 0.0333, 0.00879]
# [False, False, False, False, False, ..., False, False, False, False, False]
# [0.0135, 0.0111, 0.0326, 0.212, -1, 0.116, -1, -1, -1]
# [False, False, False, False, False, False, False, False, False]
# [0.945, 0.0522, 0.0314, 1, 0.112, -1, 0.107]
# [True, False, False, True, False, False, False]
# [0.00748, 0.221, 0.0328, 0.77, 0.00451]
# [False, False, False, False, False]
# [0.0384, 0.0472, 0.00633, 0.99, 0.0103, 0.0222, 0.0217]
# [False, False, False, True, False, False, False]
# [0.00565, 0.106, 0.029, 0.00433, 0.692, 0.0192, -1, -1]
# [False, False, False, False, False, False, False, False]
# [0.0225, 0.0466, 0.965, 0.014, 0.012, 0.0565, 0.931, -1]
# [False, False, True, False, False, False, True, False]
# [0.0449, 0.897, 0.791, 0.0321, 0.044, 0.00803]
# [False, True, False, False, False, False]
# [0.0154, 0.754, 0.122, 0.000784, 0.0106, -1, -1, -1]
# [False, False, False, False, False, False, False, False]
# [0.0261, 0.0796, 0.00517, 0.036, 0.0121, 0.94]
# [False, False, False, False, False, True]
# [0.0619, 0.0515, 0.00212, 0.00432, 0.0159, 0.0726, 0.0163, 0.997, 0.0482]
# [False, False, False, False, False, False, False, True, False]
# [0.0119, 0.88, 0.427, 0.0298, 0.0652, 0.00181, -1, -1, -1, -1, -1]
# [False, True, False, False, False, ..., False, False, False, False, False]
# [0.0728, 0.0352, 0.989, 0.0591, 1, 0.0159, 0.00965, 0.0475, -1, -1]
# [False, False, True, False, True, False, False, False, False, False]
# [0.0454, 0.0252, 0.842, 0.292, 0.0387]
# [False, False, True, False, False]
# [0.0753, 0.0214, 0.0163, 0.0367, 1, 0.00543, 0.00961, 0.0115]
# [False, False, False, False, True, False, False, False]
# [0.0367, 0.0314, 0.999, 0.0106, 0.118, -1, 0.00806, -1]
# [False, False, True, False, False, False, False, False]
# [0.0179, 0.991, 0.974, 0.0283, 0.0584, -1, -1]
# [False, True, True, False, False, False, False]
# [0.0733, 0.964, 0.592]
# [False, True, False]
# [0.533, 0.0213, 0.963, 0.036, 0.00259, 0.0207, 0.0119, 0.0159, 0.13]
# [False, False, True, False, False, False, False, False, False]
# [0.0144, 0.0515, 0.0318, 0.0258, -1, 0.0147, 0.0108, -1, -1]
# [False, False, False, False, False, False, False, False, False]
# [0.253, 0.0378, 0.995, 0.0365, 0.00306, 0.0107, ..., -1, -1, 0.0113, -1, 0.0971]
# [False, False, True, False, False, ..., False, False, False, False, False]
# [0.0838, 0.0148, 0.024, 0.021, 0.0124, ..., -1, 0.0176, 0.0115, -1, 0.0146]
# [False, False, False, False, False, ..., False, False, False, False, False]
# [0.0271, 0.014, 0.00359, 0.986, 0.00878, 0.009, -1, -1]
# [False, False, False, True, False, False, False, False]
# [0.0152, 0.759, 0.0202, 0.535]
# [False, False, False, False]
# [0.0475, 0.723, 0.0295, 0.011, 0.00227, ..., 0.00518, 0.00691, -1, 0.00619]
# [False, False, False, False, False, ..., False, False, False, False, False]
# [0.0743, 0.0206, 0.996, 0.00764, 0.663, 0.00277, 0.349, 0.0906]
# [False, False, True, False, False, False, False, False]
# [0.346, 0.0375, 0.376, 0.0132, 0.0468, 0.0323, 0.347]
# [False, False, False, False, False, False, False]
# [0.315, 0.0245, 0.361, 0.0339, 0.057, -1, -1, -1]
# [False, False, False, False, False, False, False, False]
# [0.149, 0.0115, 0.892, 0.017, 0.987, 0.0469, 0.002, 0.00571, 0.0334]
# [False, False, True, False, True, False, False, False, False]
# [0.0129, 0.932, 0.206, 0.028, 0.0251, 0.00428, -1]
# [False, True, False, False, False, False, False]
# [0.0217, 0.0238, 0.0142, 0.973, 0.0213, ..., -1, 0.00259, 0.042, 0.0204]
# [False, False, False, True, False, ..., False, False, False, False, False]
# [0.0289, 0.0193, 0.0727, 0.389, 0.00556, 0.219]
# [False, False, False, False, False, False]
# [0.00929, 0.557, 0.155, 0.00269, 0.95, -1, -1, -1, -1, 0.0199]
# [False, False, False, False, True, False, False, False, False, False]
# [0.0134, 0.0225, 0.0328, 0.856]
# [False, False, False, True]
# [0.00716, 0.388, 0.0314, 0.577, 0.00429, 0.125]
# [False, False, False, False, False, False]
# [0.0106, 0.172, 0.0314, -1, 0.00259, 0.164]
# [False, False, False, False, False, False]
# [0.0522, 0.845, 0.462, 0.0255, 0.00497, 0.325, 0.00892]
# [False, True, False, False, False, False, False]
# [0.25, 0.0176, 0.0333, 0.998, 0.00448, 0.00597, 0.0189]
# [False, False, False, True, False, False, False]
# [0.142, 0.97, 0.032, -1, 0.014, 0.584, -1]
# [False, True, False, False, False, False, False]
# [0.782, 0.0158, 0.0256, 0.00379, 0.0177, 1]
# [False, False, False, False, False, True]
# [0.0496, 0.0551, 0.987, 0.971, 0.228, -1, -1, 0.147]
# [False, False, True, True, False, False, False, False]
# [0.838, 0.0205, 0.999, 0.00954, 0.0255, -1, -1, -1]
# [True, False, True, False, False, False, False, False]
# [0.0248, 0.0287, 0.0911, 0.00378, 0.0599, 0.0128, 0.0263, -1, -1]
# [False, False, False, False, False, False, False, False, False]
# [0.0431, 0.252, 0.0229, 0.917, 0.0137, 0.00606]
# [False, False, False, True, False, False]
# [0.0171, 0.334, 0.963, 0.067, 0.0174, 0.0104, 0.993]
# [False, False, True, False, False, False, True]
# [0.0173, 0.0489, 0.406, 0.0231, 0.0618, 0.00488]
# [False, False, False, False, False, False]
# [0.998, 0.0539, 0.119, 0.0321, 0.00576, 0.0139]
# [True, False, False, False, False, False]
# [0.444, 0.603, 0.11, 0.0513, 0.00303, 0.00643]
# [False, False, False, False, False, False]
# [0.0698, 0.0208, 0.736, 0.0335, 0.00723, -1]
# [False, False, False, False, False, False]
# [0.0106, 0.0301, 0.878, 0.0116, 0.0217, ..., 0.00594, 0.938, 0.00421, 0.0107]
# [False, False, True, False, False, False, False, True, False, False]
# [0.0435, 0.986, 0.0331, 0.0156, 0.00279, -1, 0.0115, -1]
# [False, True, False, False, False, False, False, False]
# [0.215, 0.993, 0.094, 0.0302, 0.00451, 0.0377]
# [False, True, False, False, False, False]
# [0.0696, 0.94, 0.228, 0.0312, 0.00377, -1, 0.00596, -1]
# [False, True, False, False, False, False, False, False]
# [0.996, 0.0193, 0.0759, 0.99, 0.0116, 0.0183]
# [True, False, False, True, False, False]
# [0.0211, 0.987, 0.996, 0.00724, 0.0382, -1, -1]
# [False, True, True, False, False, False, False]
# [0.0243, 0.0972, 0.876, 0.0251, 0.00662, -1, -1, -1, -1, -1]
# [False, False, True, False, False, False, False, False, False, False]
# [0.81, 0.919, 0.0233, 0.0474, 0.999, 0.0252, -1, -1, -1]
# [True, True, False, False, True, False, False, False, False]
# [0.0541, 0.00905, 0.95, 0.0334, -1, 0.0129, 0.0258, -1]
# [False, False, True, False, False, False, False, False]
# [0.0646, 0.0358, 0.597, 0.937, 0.0426, 0.00351, -1, 0.0124, 0.398, -1]
# [False, False, False, True, False, False, False, False, False, False]
# [0.0154, 0.998, 0.0659, 0.0446, -1, -1, -1, -1, 0.00783]
# [False, True, False, False, False, False, False, False, False]
# [0.0262, 0.0186, 1, 0.0147, 0.983, 0.00394, -1, -1]
# [False, False, True, False, True, False, False, False]
# [0.0247, 0.59, 0.88, 0.0239, 0.0123, 0.0136]
# [False, False, True, False, False, False]
# [0.037, 0.814, 0.0305, 0.25, 0.00557, -1, 0.0146, -1, -1]
# [False, True, False, False, False, False, False, False, False]
# [0.0552, 0.0281, 0.0306, 0.988, 0.221, 0.999, 0.00523, 0.00853]
# [False, False, False, True, False, True, False, False]
# [0.0348, 0.407, 0.955, 0.0322, -1, 0.0165]
# [False, False, True, False, False, False]
# [0.0643, 0.615, 0.999, 0.0225]
# [False, False, True, False]
# [0.0125, 0.0456, 0.00498, 0.0205, 0.69, -1]
# [False, False, False, False, False, False]
# [0.0164, 0.0414, 0.0328, -1, 0.645, -1]
# [False, False, False, False, False, False]
# [0.0851, 0.0154, 0.0515, 0.993]
# [False, False, False, True]
# [0.0724, 0.0994, 0.998, 0.0417, 0.0634, 0.0107]
# [False, False, True, False, False, False]
# [0.0135, 0.035, 0.00553, 0.692, 0.999, 0.00544, 0.00329, 0.00388, -1]
# [False, False, False, False, True, False, False, False, False]
# [0.0263, 0.0271, 0.039, 0.035, 0.988, 1, 0.13, 0.0789]
# [False, False, False, False, True, True, False, False]
# [0.0718, 0.0362, 0.0395, 0.00246, 0.0569, -1, -1]
# [False, False, False, False, False, False, False]
# [0.0253, 0.0284, 0.0453, 0.00452, 0.0114, ..., 0.9, 0.00649, -1, 0.0414, 0.0107]
# [False, False, False, False, False, ..., True, False, False, False, False]
# [0.0319, 0.0774, 0.954, 0.504]
# [False, False, True, False]
# [0.0291, 0.983, 0.402, 0.168, -1, -1]
# [False, True, False, False, False, False]
# [0.0235, 0.00806, 0.965, 0.035, 0.0134, 1, 0.0173, 0.0225, -1]
# [False, False, True, False, False, True, False, False, False]
# [0.0387, 0.999, 0.208, 0.0844, 0.00432, 0.134, 0.0066, 0.112, -1]
# [False, True, False, False, False, False, False, False, False]
# [0.0125, 0.0262, 0.526, 0.263, 0.00752, 0.00681, -1, 0.017]
# [False, False, False, False, False, False, False, False]
# [0.0155, 0.0168, 0.0166, 0.0112, 0.0438, 0.0648, 0.0433, -1]
# [False, False, False, False, False, False, False, False]
# [0.0354, 0.0138, 0.0258, 0.0286, 0.872, 0.999, -1, 0.0285, 0.0172, -1, -1]
# [False, False, False, False, True, True, False, False, False, False, False]
# [0.0413, 0.0115, 0.0199, 0.582, 0.919, -1, -1]
# [False, False, False, False, True, False, False]
# [0.0229, 0.692, 0.0056, 0.0159, 0.288, ..., 0.0134, 0.0119, 0.0254, -1, -1]
# [False, False, False, False, False, ..., False, False, False, False, False]
# [0.0402, 0.029, -1, 0.0443, 0.795, 0.409, -1, -1]
# [False, False, False, False, False, False, False, False]
# [0.00946, 0.0219, 0.996, 0.0268, 0.99, -1]
# [False, False, True, False, True, False]
# [0.0144, 0.0157, 0.985, 0.999, 0.00208, -1]
# [False, False, True, True, False, False]
# [0.0168, 0.0233, 0.0347, 0.0427, 0.0808, 0.00274, ..., 0.994, 0.12, -1, -1, -1]
# [False, False, False, False, False, ..., True, False, False, False, False]
# [0.0492, 0.998, 0.994, 0.403, 0.0963, 0.02, ..., 0.0115, 0.00527, -1, -1, -1]
# [False, True, True, False, False, False, ..., False, False, False, False, False]
# [0.0233, 0.0295, 0.03, 0.999, 0.0851]
# [False, False, False, True, False]
# [0.286, 0.0604, 0.0203, 0.00724, 0.032, -1]
# [False, False, False, False, False, False]
# [0.028, 0.36, 0.0341, 0.00314, 0.0677]
# [False, False, False, False, False]
# [0.11, 0.0559, 0.0301, 0.00471, 0.00488, -1, -1, 0.984, 0.073]
# [False, False, False, False, False, False, False, True, False]
# [0.0214, 0.0375, 1, 0.409, 0.0724, 0.0104, 0.0282, -1]
# [False, False, True, False, False, False, False, False]
# [0.344, 0.0273, 0.0738, 0.0285, -1, -1]
# [False, False, False, False, False, False]
# [0.009, 0.12, 1, 0.172, 0.0164, 0.119]
# [False, False, True, False, False, False]
# [0.057, 0.949, 0.99, 0.0312, 0.0145, 0.109, 0.00434]
# [False, True, True, False, False, False, False]
# [0.481, 0.0978, 0.0619, 0.0354, 0.996, 0.0413]
# [False, False, False, False, True, False]
# [0.0334, 0.998, 0.00384, 0.234, 0.0222, 0.0153, -1]
# [False, True, False, False, False, False, False]
# [0.0157, 0.74, 0.0756, 0.0352, 0.999, 0.00395, 0.0035, 0.023, 0.0124]
# [False, False, False, False, True, False, False, False, False]
# [0.0294, 0.797, 0.0266, 0.0997, 0.99]
# [False, False, False, False, True]
# [0.0155, 0.0366, 0.195, 0.998, 0.00601, 0.0108, -1, -1, -1, -1, -1, -1, -1]
# [False, False, False, True, False, ..., False, False, False, False, False]
# [0.0406, 0.799, 0.0281, 0.919, 0.00786, 0.0461]
# [False, False, False, True, False, False]
# [0.00619, 0.977, 0.0537, 0.219, 0.851, 0.00676, -1]
# [False, True, False, False, True, False, False]
# [0.00848, 0.032, 0.639, 0.0655, 0.0293, 0.0195]
# [False, False, False, False, False, False]
# [0.0351, 0.0375, 0.997, 0.914, 0.0349, 0.00337, 0.00382, 0.237, -1]
# [False, False, True, True, False, False, False, False, False]
# [0.0377, 0.0962, 0.0254, 0.995, -1]
# [False, False, False, True, False]
# [0.0375, 0.0273, 0.33, 0.0149, 0.999, 0.303, -1]
# [False, False, False, False, True, False, False]
# [0.0437, 0.0273, 0.0298, 0.305, 0.00543, 0.979, ..., 0.00369, -1, -1, -1, -1]
# [False, False, False, False, False, ..., False, False, False, False, False]
# [0.0216, 0.0145, 0.837, 0.15, 0.0259, 0.0063, -1, 0.00822, 0.0259, 0.0238]
# [False, False, True, False, False, False, False, False, False, False]
# [0.0259, 0.0356, 1, 0.0021, 0.999, 0.00496, 0.0256, -1]
# [False, False, True, False, True, False, False, False]
# [0.0294, 0.0139, 0.0168, 0.996, 0.00219, 0.117, -1]
# [False, False, False, True, False, False, False]
# [0.043, 0.0233, 0.744, 0.156, 0.00642, ..., 0.826, 0.0137, 0.0133, 0.0174]
# [False, False, False, False, False, False, True, False, False, False]
# [0.0573, 0.0668, 0.193, 0.824, 0.0831, 0.395, 0.0789]
# [False, False, False, True, False, False, False]
# [0.0299, 0.807, 0.0238, 0.981]
# [False, True, False, True]
# [0.142, 0.179, 0.0298, 0.00491, 0.999, -1, 0.0306, -1, -1, -1]
# [False, False, False, False, True, False, False, False, False, False]
# [0.0348, 0.0322, 0.699, 1, -1, -1, -1]
# [False, False, False, True, False, False, False]
# [0.0389, 0.0287, 0.0248, 0.992, 0.00426, -1, -1, 0.0121]
# [False, False, False, True, False, False, False, False]
# [0.00784, 0.0387, 0.999, 0.0117, 0.45, 0.0106]
# [False, False, True, False, False, False]
# [0.022, 0.536, 0.0819, -1, 0.0102, 0.0336, -1]
# [False, False, False, False, False, False, False]
# [0.0417, 0.0387, 0.0125, 0.0042, 0.0482, -1]
# [False, False, False, False, False, False]
# [0.0739, 0.0258, 0.0292, 0.0203, 0.329, 0.00519, -1, 0.0465, 0.00782]
# [False, False, False, False, False, False, False, False, False]
# [0.0988, 0.227, 0.0254, 0.0112, 0.045, 0.0133, 0.00351, 1, 0.00783, -1, -1]
# [False, False, False, False, False, ..., False, True, False, False, False]
# [0.0139, 0.0117, 0.0181, 0.0427, 0.00281, 0.0312, -1, -1]
# [False, False, False, False, False, False, False, False]
# [0.0577, 0.0125, 1, 0.0114, 0.988, 0.0079, ..., -1, -1, 0.00655, -1, -1, 0.325]
# [False, False, True, False, True, False, ..., False, False, False, False, False]
# [0.0242, 0.0352, 0.44, 0.968, -1]
# [False, False, False, True, False]
# [0.024, 0.571, 0.0193, 0.0768, 0.00633, -1, 0.916, 0.00469]
# [False, False, False, False, False, False, True, False]
# [0.289, 0.198, 0.0757, 0.999, 0.0338, -1, -1, -1, -1]
# [False, False, False, True, False, False, False, False, False]
# [0.0343, 0.0641, 0.977, 0.00225, 0.00432, -1]
# [False, False, True, False, False, False]
# [0.0346, 0.0151, 0.957, 0.15, -1, 0.0102, 0.0732]
# [False, False, True, False, False, False, False]
# [0.0765, 0.0243, 0.0249, 0.997, 0.00777, 0.0263, -1, 0.00597]
# [False, False, False, True, False, False, False, False]
# [0.0385, 0.307, 0.0221, 0.572, 0.0164, 0.00255, -1, 0.0293, -1]
# [False, False, False, False, False, False, False, False, False]
# [0.0347, 0.0304, 0.916, -1, 1, 0.0264, 0.00797, 0.121, -1, -1]
# [False, False, True, False, True, False, False, False, False, False]
# [0.126, 0.0188, 0.00567, 0.0378, 0.293, 0.0135]
# [False, False, False, False, False, False]
# [0.00885, 0.0152, 0.0391, 0.985, 0.00359, 0.00517, 0.015, -1]
# [False, False, False, True, False, False, False, False]
# [0.014, 0.177, 0.0353, 0.00965, 0.0058, 0.0033, -1]
# [False, False, False, False, False, False, False]
# [0.4, 0.0325, 0.0773, 0.998, 0.00258, ..., 0.0164, 0.00488, 0.218, 0.0164, -1]
# [False, False, False, True, False, ..., False, False, False, False, False]
# [0.0456, 0.0153, 0.0562, 0.3, 0.00611, 0.0107, 0.0241, 0.023, -1]
# [False, False, False, False, False, False, False, False, False]
# [0.0332, 0.0354, 0.883, 0.999, 0.00427, 0.0846, -1, -1]
# [False, False, True, True, False, False, False, False]
# [0.0266, 0.998, 0.531, 0.0174, 0.0725, -1, -1, 0.0319, -1, -1, -1]
# [False, True, False, False, False, ..., False, False, False, False, False]
# [0.0307, 0.304, 0.0567, 0.993, 0.997, 0.138, 0.00707, 0.0265]
# [False, False, False, True, True, False, False, False]
# [0.0274, 0.997, 0.0114, 0.0308, -1]
# [False, True, False, False, False]
# [0.306, 0.0318, 0.0555, 0.999, 0.00954, 0.0155, 0.0159, 0.0171]
# [False, False, False, True, False, False, False, False]
# [0.0281, 0.0447, 0.887, 0.0352, 0.0296, -1]
# [False, False, True, False, False, False]
# [0.0274, 0.969, 0.0306, 0.825, 0.37, -1, -1]
# [False, True, False, True, False, False, False]
# [0.00739, 0.942, 0.0152, 1]
# [False, True, False, True]
# [0.398, 0.0435, 0.361, 0.1, 0.21, 0.00387, -1, 0.00467, 0.014]
# [False, False, False, False, False, False, False, False, False]
# [0.0536, 0.0831, 0.0111, 0.994]
# [False, False, False, True]
# [0.0256, 0.0229, 1, 0.00717, 0.092]
# [False, False, True, False, False]
# [0.0166, 0.0371, 0.697, 0.183, 0.0831, 0.0495, 0.0112, 0.0152, -1]
# [False, False, False, False, False, False, False, False, False]
# [0.0238, 0.041, 0.46, 0.0359, 0.0572, 0.0297]
# [False, False, False, False, False, False]
# [0.0355, 0.222, 0.0352, 0.0078, 1, 0.999, -1, 0.00601, 0.00867]
# [False, False, False, False, True, True, False, False, False]
# [0.0126, 0.999, 0.0202, 0.0125, -1, 0.0205, 0.00681, 0.00401, 0.0636]
# [False, True, False, False, False, False, False, False, False]
# [0.0253, 0.0158, 0.0277, 1, 0.0105, 0.0267, -1]
# [False, False, False, True, False, False, False]
# [0.0298, 0.0984, 0.0392, 0.892, 0.0131, 0.985, -1, -1, -1, -1]
# [False, False, False, True, False, True, False, False, False, False]
# [0.0138, 0.987, 0.0339, 0.00155, 0.137, 0.876, -1, -1]
# [False, True, False, False, False, True, False, False]
# [0.0197, 0.786, 0.0299, 0.469, 0.999]
# [False, False, False, False, True]
# [0.0189, 0.911, 0.988, -1, 0.0059, 0.0173, ..., -1, 0.00602, -1, -1, -1]
# [False, True, True, False, False, False, ..., False, False, False, False, False]
# [0.0957, 0.0321, 0.995, 0.0686, 0.00616, 0.0393, 0.0109, -1]
# [False, False, True, False, False, False, False, False]
# [0.0244, 0.0246, 0.0458, 0.0632, 0.263, 0.00806]
# [False, False, False, False, False, False]
# [0.0218, 0.0371, 0.609, 0.949, -1]
# [False, False, False, True, False]
# [0.038, 0.0148, 0.0151, 0.969, 0.0171, 0.0645, 0.107, -1, -1]
# [False, False, False, True, False, False, False, False, False]
# [0.0449, 0.0737, 0.0344, 0.0261, 0.0504, 0.0295, 0.0143, -1]
# [False, False, False, False, False, False, False, False]
# [0.0257, 0.0159, 0.0121, 0.976, 0.856, 0.00487]
# [False, False, False, True, True, False]
# [0.0577, 0.0141, 0.0264, 0.968, 0.376]
# [False, False, False, True, False]
# [0.0182, 0.922, 0.0299, 0.00687, 0.987, 0.00275, 0.0117, 0.0876]
# [False, True, False, False, True, False, False, False]
# [0.0407, 0.0578, 1, 0.0178, 0.00176, 0.00394, 0.997, -1, -1]
# [False, False, True, False, False, False, True, False, False]
# [0.00536, 0.185, 0.0226, 0.00219, 0.00409, ..., 0.0019, 0.0167, -1, -1, -1]
# [False, False, False, False, False, ..., False, False, False, False, False]
# [0.0415, 0.0488, 0.0229, 1, 0.996, 0.0868, 0.0268, -1]
# [False, False, False, True, True, False, False, False]
# [0.885, 0.0264, 0.00403, 0.0148]
# [True, False, False, False]
# [0.0334, 0.024, 0.00839, 0.0116, 1, 0.992, 0.00396, 0.00189, 0.00983]
# [False, False, False, False, True, True, False, False, False]
# [0.0303, 0.0174, 0.02, 0.937, 0.791, -1, 0.0212, -1, -1]
# [False, False, False, True, False, False, False, False, False]
# [0.0378, 0.0123, 0.0226, 0.0211, 0.0162, 0.0034, -1]
# [False, False, False, False, False, False, False]
# [0.0311, 0.0237, 0.0941, 0.991, 0.0596, 0.465, 0.996, 0.0441, -1]
# [False, False, False, True, False, False, True, False, False]
# [0.0262, 0.985, 0.925, 0.0396, 0.008, 0.0155]
# [False, True, True, False, False, False]
# [0.176, 0.0458, 0.022, 0.00893]
# [False, False, False, False]
# [0.029, 0.0262, 0.862, 0.979, 0.00666, -1, -1]
# [False, False, True, True, False, False, False]
# [0.0254, 0.081, 0.0459, -1, 0.0148, -1, 0.0232, -1, 0.0673]
# [False, False, False, False, False, False, False, False, False]
# [0.0412, 0.0574, 1, 0.0293, 0.00618, 0.495, 0.0737]
# [False, False, True, False, False, False, False]
# [0.0335, 0.0285, 0.999, 0.0213, 0.00682, ..., 0.997, 0.0117, 0.0462, -1, -1]
# [False, False, True, False, False, False, True, False, False, False, False]
# [0.0329, 0.0166, 0.975, 0.999, 0.0027, 0.0137]
# [False, False, True, True, False, False]
# [0.0191, 0.993, 0.0156, 0.0817, 0.0409, 0.061, 0.0065]
# [False, True, False, False, False, False, False]
# [0.00558, 0.851, 0.0961, 0.0294, 0.0567, 0.0156, 0.0173]
# [False, True, False, False, False, False, False]
# [0.0329, 0.997, 0.234, 0.0238, 0.0136, 0.0104, -1, 0.043]
# [False, True, False, False, False, False, False, False]
# [0.0307, 0.975, 0.00549, 0.0217, 0.974]
# [False, True, False, False, True]
# [0.0328, 0.18, 0.995, 0.0159, 0.0385, -1, 0.168, 0.0378]
# [False, False, True, False, False, False, False, False]
# [0.0853, 0.7, 0.0411, 0.0084, 1, 0.0459, 0.00978, -1, 0.00672, -1]
# [False, False, False, False, True, False, False, False, False, False]
# [0.0281, 0.953, 0.951, 0.0188, -1, -1]
# [False, True, True, False, False, False]
# [0.0311, 0.723, 0.119, 0.032, -1]
# [False, False, False, False, False]
# [0.037, 0.0218, 0.0471, 0.407, 0.00742, -1]
# [False, False, False, False, False, False]
# [0.0401, 0.577, 0.996, 0.0312, 0.103, 0.0122, 0.0112]
# [False, False, True, False, False, False, False]
# [0.103, 0.0857, 0.0208, 0.968, -1, 0.0063, 0.0164, 0.018]
# [False, False, False, True, False, False, False, False]
# [0.0201, 0.0279, 0.666, 0.0795, 0.0497, 0.0118, 0.00225, 0.00625]
# [False, False, False, False, False, False, False, False]
# [0.123, 0.0305, 0.663, 0.0411, 0.0231, 0.00467, 0.00761, 0.00802, 0.0059]
# [False, False, False, False, False, False, False, False, False]
# [0.0291, 0.0142, 0.99, 0.0251, 0.00474, 0.817, 0.0155, -1, -1]
# [False, False, True, False, False, True, False, False, False]
# [0.0267, 0.0143, 0.0092, 0.0234, 0.82, 0.0434, -1, 0.0242, 0.0107, -1]
# [False, False, False, False, True, False, False, False, False, False]
# [0.729, 0.0683, 0.0273, 1, 0.0136, 0.0202, 0.0208, 0.0153, -1]
# [False, False, False, True, False, False, False, False, False]
# [0.0152, 0.0219, 0.0645, 0.999, 0.00592, -1]
# [False, False, False, True, False, False]
# [0.0243, 0.0145, 0.244, 0.997, 0.137, 0.185]
# [False, False, False, True, False, False]
# [0.0288, 0.0104, 0.0242, 0.0231, 0.648, 0.0864, -1]
# [False, False, False, False, False, False, False]
# [0.0187, 0.618, 0.293, 0.208, -1]
# [False, False, False, False, False]
# [0.0271, 0.0966, 0.00944, 0.979, 0.989, -1, 0.006, 0.00619, -1, -1]
# [False, False, False, True, True, False, False, False, False, False]
# [0.0229, 0.00996, 0.228, 0.00198, 0.995, 0.00781]
# [False, False, False, False, True, False]
# [0.0337, 0.0356, 0.00957, 0.00758, 0.999, ..., 0.00236, 0.00552, 0.996, -1]
# [False, False, False, False, True, False, False, False, True, False]
# [0.0136, 0.0287, 0.404, 0.952, 0.00925, 0.0187, 0.0241, -1, -1]
# [False, False, False, True, False, False, False, False, False]
# [0.044, 0.0488, 0.258, 0.768, 0.00319, 0.0126, 0.14]
# [False, False, False, False, False, False, False]
# [0.0405, 0.0169, 0.999, 0.999, 0.00641, 0.0235, 0.0134]
# [False, False, True, True, False, False, False]
# [0.0333, 0.996, 0.00483, 0.022, 0.933, -1, -1, -1, -1, -1]
# [False, True, False, False, True, False, False, False, False, False]
# [0.0088, 0.0144, 0.0533, 0.00396, 1, 0.00233, -1, -1, -1]
# [False, False, False, False, True, False, False, False, False]
# [0.03, 0.979, 0.0189, 0.849, 0.00312, 0.0384, 0.0444]
# [False, True, False, True, False, False, False]
# [0.0751, 0.0525, 0.984, 0.022, 0.0069, 0.0268, -1]
# [False, False, True, False, False, False, False]
# [0.0175, 0.0232, 0.344, 0.0214, 0.0771, ..., -1, 0.00957, 0.00418, 0.0445]
# [False, False, False, False, False, ..., False, False, False, False, False]
# [0.0282, 0.289, 0.0297, 0.996, 0.00738, 0.00658, 0.00578, -1, 0.0472]
# [False, False, False, True, False, False, False, False, False]
# [0.0304, 0.177, 0.206, 0.0357, 0.00268, 0.162, 0.0829, -1]
# [False, False, False, False, False, False, False, False]
# [0.0385, 0.0357, 0.992, 0.0285, 0.00797, 0.038]
# [False, False, True, False, False, False]
# [0.996, 0.0422, 0.0181, 0.966, 0.0204, ..., 0.0125, -1, 0.0167, 0.04, -1]
# [True, False, False, True, False, False, ..., False, False, False, False, False]
# [0.0451, 0.0154, 0.0145, 0.735, 0.00805, 0.999, 0.00993, -1, -1]
# [False, False, False, False, False, True, False, False, False]
# [0.677, 0.0854, 0.0207, 0.00344, 0.999, 0.0177, -1, -1]
# [False, False, False, False, True, False, False, False]
# [0.982, 0.0306, 0.0487, 0.176, 0.888, 0.0237, 0.0857, 0.0191]
# [True, False, False, False, True, False, False, False]
# [0.00871, 0.0128, 0.0239, 0.968, 0.121, 0.00696, -1]
# [False, False, False, True, False, False, False]
# [0.0172, 0.993, 0.0276, 0.0225, 0.998, 0.0638, -1, 0.0157, 0.0511, -1]
# [False, True, False, False, True, False, False, False, False, False]
# [0.0259, 0.0383, 0.0834, 0.0271, 0.712, 0.0306, 0.0204]
# [False, False, False, False, False, False, False]
# [0.0311, 0.826, 0.0284, 0.0186, 1, 0.0122, 0.0153, -1, -1, -1, -1]
# [False, True, False, False, True, False, False, False, False, False, False]
# [0.0165, 0.136, 0.0231, 0.362, -1, 0.00955, 0.0171]
# [False, False, False, False, False, False, False]
# [0.0182, 0.0589, 0.998, 0.0216, -1, -1, -1, -1, -1]
# [False, False, True, False, False, False, False, False, False]
# [0.79, 0.0849, 0.996, 0.0199, 0.172, ..., 0.00802, 0.00832, 0.00448, 0.0147]
# [False, False, True, False, False, False, False, False, False, False]
# [0.0117, 0.0309, 0.0307, 0.0537, 0.00322, 0.00854, -1]
# [False, False, False, False, False, False, False]
# [0.014, 0.047, 0.0347, 0.994, 0.0346, 0.00447, 0.0502, 0.764]
# [False, False, False, True, False, False, False, False]
# [0.0154, 0.0235, 0.998, 0.862, 0.0404, 0.108, 0.00521, 0.0142, 0.00637, -1]
# [False, False, True, True, False, False, False, False, False, False]
# [0.104, 0.25, 0.0143, 0.996, 0.0367, 0.0192, -1, -1]
# [False, False, False, True, False, False, False, False]
# [0.039, 0.31, 0.718, 0.00618, -1, 0.232]
# [False, False, False, False, False, False]
# [0.0535, 0.59, 0.0251, 0.00502, 0.00335, 0.0224, 0.0279, 0.0531]
# [False, False, False, False, False, False, False, False]
# [0.0318, 0.0233, 0.964, 0.00542, 0.0126, 0.403, 0.905, 0.00172, -1, -1]
# [False, False, True, False, False, False, True, False, False, False]
# [0.0234, 0.988, 0.974, 0.0405]
# [False, True, True, False]
# [0.201, 0.117, 0.35, 0.00408, 0.00196, 0.0189, 0.017]
# [False, False, False, False, False, False, False]
# [0.0292, 0.981, 0.0302, 0.0256, 0.793, 0.0208]
# [False, True, False, False, False, False]
# [0.0311, 0.0187, 0.0977, 0.636, 0.00387, -1]
# [False, False, False, False, False, False]
# [0.0319, 0.00826, 0.938, 0.0251, 0.00831, 1, 0.04, -1, -1, 0.00931, -1]
# [False, False, True, False, False, True, False, False, False, False, False]
# [0.0282, 0.991, 0.039, 0.0506, 0.997, 0.0126, 0.00571]
# [False, True, False, False, True, False, False]
# [0.0119, 0.017, 0.862, 0.742, 0.011, 0.0264, 0.0714]
# [False, False, True, False, False, False, False]
# [1, 0.0269, 0.0254, 0.996, 0.00952, 0.0123]
# [True, False, False, True, False, False]
# [0.0151, 0.993, 0.258, 0.0337, 0.00983, 0.00951, 0.0157, -1]
# [False, True, False, False, False, False, False, False]
# [0.0163, 0.0828, 1, 0.12, 0.999, 0.00754, 0.0209]
# [False, False, True, False, True, False, False]
# [0.0338, 0.0156, 0.998, 0.01, 0.956, -1]
# [False, False, True, False, True, False]
# [0.0478, 0.00369, 0.0277, 0.997, 0.044, 0.997]
# [False, False, False, True, False, True]
# [0.0262, 0.00806, 0.994, 0.0573, 0.966, 0.0813, 0.0471, -1, -1]
# [False, False, True, False, True, False, False, False, False]
# [0.0129, 0.147, 0.00422, 0.812, 0.0154, 0.0203, -1]
# [False, False, False, True, False, False, False]
# [-1, 0.165, 0.862, 0.0425, 0.0136, 0.00613]
# [False, False, True, False, False, False]
# [0.0295, 0.0414, 0.998, 0.261, 0.00309, 0.0404, 0.00577, 0.0155, -1]
# [False, False, True, False, False, False, False, False, False]
# [0.0227, 0.0241, 0.00631, 0.00756, 0.103, ..., 0.981, -1, 0.136, -1, 0.0259]
# [False, False, False, False, False, ..., True, False, False, False, False]
# [0.0699, 0.0266, 0.0323, 0.011, 0.476, 0.0451, 0.00631, 0.0338]
# [False, False, False, False, False, False, False, False]
# [0.0262, 0.724, 0.0471, 0.999, 0.0403, 0.0327]
# [False, False, False, True, False, False]
# [0.0251, 0.936, 0.0282, 0.989, 0.00367, 0.0147, 0.0108, 0.0135]
# [False, True, False, True, False, False, False, False]
# [0.0143, 0.0709, 0.0446, 0.452, 1, 0.00378, -1]
# [False, False, False, False, True, False, False]
# [0.0108, 0.02, 0.0143, 0.00505, 0.851, 0.165, -1, -1]
# [False, False, False, False, True, False, False, False]
# [0.0238, 0.0169, 0.0329, 0.0501, 0.0114, 0.0297]
# [False, False, False, False, False, False]
# [0.0323, 0.473, 0.0215, 0.885, 0.0103, 0.0028, 0.119]
# [False, False, False, True, False, False, False]
# [0.116, 0.022, 0.133, 0.659, 0.0148, 0.0133]
# [False, False, False, False, False, False]
# [0.0201, 0.156, 0.688, -1, -1]
# [False, False, False, False, False]
# [0.034, 0.449, 0.616, 0.0373, 0.00589, -1, 0.675, -1]
# [False, False, False, False, False, False, False, False]
# [0.0362, 0.0294, 0.999, 0.999, 0.0323, 0.0167, 0.0182]
# [False, False, True, True, False, False, False]
# [0.0445, 0.996, 0.0771, 0.993, 0.0375]
# [False, True, False, True, False]
# [0.0369, 0.0313, 0.0217, 0.993, 0.999, 0.0221, -1]
# [False, False, False, True, True, False, False]
# [0.375, 0.00893, 0.0121, 0.0104, 0.626, 0.0171, 0.039, -1]
# [False, False, False, False, False, False, False, False]
# [0.0269, 0.0148, 0.00678, 0.997, 0.989, 0.00165, -1]
# [False, False, False, True, True, False, False]
# [0.571, 0.101, 0.0208, 0.942, 0.00553, -1, -1, -1]
# [False, False, False, True, False, False, False, False]
# [0.00697, 0.989, 0.395, 0.0197, 0.00289]
# [False, True, False, False, False]
# [0.0136, 0.253, 1, 0.0327, 0.00326, 0.0407, 0.00867, 0.0331]
# [False, False, True, False, False, False, False, False]
# [0.0395, 0.116, 0.00728, 0.0229, 0.0141, 0.00536, 0.0052, -1]
# [False, False, False, False, False, False, False, False]
# [0.0323, 0.806, 0.105, 0.019, 0.0292, ..., 0.00193, 0.00499, 0.00877, 0.0268]
# [False, True, False, False, False, True, False, False, False, False]
# [0.0419, 0.0219, 0.982, 0.0515, 0.0288]
# [False, False, True, False, False]
# [0.0141, 0.00727, 0.0653, 0.976, 0.916, 0.0266]
# [False, False, False, True, True, False]
# [0.0316, 0.11, 0.0255, 0.313, 0.00355, 0.00864, 0.0422, 0.384]
# [False, False, False, False, False, False, False, False]
# [0.0527, 1, 0.994, 0.0249, 0.0339, ..., 0.00513, -1, 0.0165, 0.0153, 0.00847]
# [False, True, True, False, False, False, ..., False, False, False, False, False]
# [0.264, 0.0294, 0.0757, 0.0629, 0.0583, 0.00487, 0.99, -1, -1, -1]
# [False, False, False, False, False, False, True, False, False, False]
# [0.0303, 0.0644, 0.00336, 0.038, 0.01, 0.0307, 0.0526, -1]
# [False, False, False, False, False, False, False, False]
# [0.0624, 0.0708, 0.0171, 0.646, 0.0122, 0.357, -1, 0.0252]
# [False, False, False, False, False, False, False, False]
# [0.0212, 0.173, 0.185, 0.0383, -1]
# [False, False, False, False, False]
# [0.0352, 0.0228, 0.894, 0.991, 0.0776, ..., 0.0306, 0.0262, 0.39, -1, -1]
# [False, False, True, True, False, False, False, False, False, False, False]
# [0.0541, 0.106, 0.018, 0.994, 0.00257, 0.00478, -1, -1]
# [False, False, False, True, False, False, False, False]
# [0.035, 0.0345, 0.062, 0.984, 0.992, -1, -1, -1]
# [False, False, False, True, True, False, False, False]
# [0.249, 0.0702, 0.294, 0.00426, 0.0125, 0.00128, 0.0115, -1]
# [False, False, False, False, False, False, False, False]
# [0.0128, 0.264, 0.0296, 0.0079, 0.0209, 0.00486]
# [False, False, False, False, False, False]
# [0.0287, 0.23, 0.0252, 0.968, 0.00117, 0.0257]
# [False, False, False, True, False, False]
# [0.0302, 0.0219, 0.971, 0.0266, -1, ..., 0.00818, 0.00782, 0.0182, 0.925]
# [False, False, True, False, False, False, False, False, False, True]
# [0.0424, 0.0249, 0.164, 0.0717, 0.14, ..., 0.0156, 0.412, 0.669, 0.032, -1]
# [False, False, False, False, False, ..., False, False, False, False, False]
# [0.017, 0.989, 0.0238, 0.923, 0.0504, 0.0123, 0.0535, 0.00755, -1, 0.092]
# [False, True, False, True, False, False, False, False, False, False]
# [0.215, 0.998, 0.0269]
# [False, True, False]
# [0.00928, 0.28, 0.0322, 0.0108, 0.0337, 0.00536]
# [False, False, False, False, False, False]
# [0.00875, 0.0979, 0.0196, 0.785, 0.0055, 0.0698]
# [False, False, False, False, False, False]
# [0.0227, 0.2, 0.0188, 0.00448, 0.0903, 0.675, 0.0105, 0.0297]
# [False, False, False, False, False, False, False, False]
# [0.0245, 0.848, 0.066, 0.905, 0.011, 0.0709, 0.0257]
# [False, True, False, True, False, False, False]
# [0.019, 0.0741, 0.0782, 0.028, 0.0499, 0.0574, 0.0132]
# [False, False, False, False, False, False, False]
# [0.0271, 0.264, 0.942, 0.0363, 0.0312, 0.0051, 0.0396, 0.0191]
# [False, False, True, False, False, False, False, False]
# [0.0456, 0.0123, 0.406, -1, 0.0373]
# [False, False, False, False, False]
# [0.502, 0.0262, 0.154, 0.037, 0.0214, 0.00654, -1]
# [False, False, False, False, False, False, False]
# [0.0276, 0.0267, 0.0328, 0.999, 0.888, 0.0911, 0.0054, -1, -1, 0.00806]
# [False, False, False, True, True, False, False, False, False, False]
# [0.982, 0.0218, 0.102, 0.95, 0.00428, 0.00473, 0.223, 0.00898]
# [True, False, False, True, False, False, False, False]
# [0.0347, 0.308, 0.00843, 0.00875, 0.99]
# [False, False, False, False, True]
# [0.0089, 0.0349, 0.0804, 0.0114, 0.00412, ..., 0.0124, 0.0272, 0.00814, -1, -1]
# [False, False, False, False, False, ..., False, False, False, False, False]
# [0.999, 0.00946, 0.0249, 1, 0.0693, 0.00469, -1]
# [True, False, False, True, False, False, False]
# [0.657, 0.0492, 0.0187, 0.539, 0.83, -1, -1]
# [False, False, False, False, True, False, False]
# [0.0197, 0.0752, 0.0565, 0.949, 0.0264, 0.0584, 0.0222, 0.108]
# [False, False, False, True, False, False, False, False]
# [0.973, 0.0387, 0.03, 0.426, 0.00984, ..., 0.775, -1, 0.0327, 0.0156, 0.0344]
# [True, False, False, False, False, ..., False, False, False, False, False]
# [0.105, 0.0692, 0.00217, 0.00983, 0.00433, 1, 0.43]
# [False, False, False, False, False, True, False]
# [0.0183, 0.765, 0.018, 0.989, 0.15, 0.205, 0.0231]
# [False, False, False, True, False, False, False]
# [0.0253, 0.999, 0.0166, 0.0572, -1, -1]
# [False, True, False, False, False, False]
# [0.017, 0.813, 0.0273, 0.49, 0.00304, 0.00468, 0.0116, -1]
# [False, True, False, False, False, False, False, False]
# [0.0745, 0.0149, 0.0293, 0.984, 0.00234, 0.999, -1, -1]
# [False, False, False, True, False, True, False, False]
# [0.0386, 0.517, 0.0209, 0.131, 0.014, 0.0144, 0.00887]
# [False, False, False, False, False, False, False]
# [0.0222, 0.0132, 0.00465, 0.00449, 0.996, ..., 0.00826, 0.00834, 0.0277, -1]
# [False, False, False, False, True, ..., False, False, False, False, False]
# [0.0238, 0.0468, 0.00704, 0.0262, 0.00893, 0.0047, 0.011, 0.372, -1]
# [False, False, False, False, False, False, False, False, False]
# [0.0296, 0.0863, 0.0292, 0.00431, 0.00398, 0.0125, 0.503, -1]
# [False, False, False, False, False, False, False, False]
# [0.00858, 0.976, 0.0323, 0.00288, 1, -1]
# [False, True, False, False, True, False]
# [0.0248, 0.0342, 1, 0.999, 0.752, 0.0409, -1, -1, -1]
# [False, False, True, True, False, False, False, False, False]
# [0.0337, 0.0248, 0.996, 0.998, 0.011, 0.00528, -1, -1]
# [False, False, True, True, False, False, False, False]
# [0.0367, 0.0392, 0.0255, 0.0114, 0.496, 0.00856, -1, 0.786]
# [False, False, False, False, False, False, False, False]
# [0.0213, 0.026, 0.0685, 1, 0.0069, 0.00275, 0.00373]
# [False, False, False, True, False, False, False]
# [0.0225, 0.187, 0.37, 0.0278, 0.00418, 0.00954, -1, -1]
# [False, False, False, False, False, False, False, False]
# [0.00881, 0.122, 0.0268, 0.0749, -1]
# [False, False, False, False, False]
# [0.0999, 0.291, 0.0895, 0.0304, 0.00379, ..., 0.998, 0.0298, 0.0355, 0.0054]
# [False, False, False, False, False, ..., False, True, False, False, False]
# [0.0226, 0.0351, 0.898, 0.018, 0.185, 1, 0.00236, 0.0387, 0.0128]
# [False, False, True, False, False, True, False, False, False]
# [0.0149, 0.0192, 0.991, 0.0118, 0.239, 0.00228, -1]
# [False, False, True, False, False, False, False]
# [0.0404, 0.0157, 0.00694, 1, 0.929]
# [False, False, False, True, True]
# [0.038, 0.091, 0.991, 0.0488, 0.00522, 0.00833, 0.00495, 0.165]
# [False, False, True, False, False, False, False, False]
# [0.00347, 0.527, 0.752, 0.0381, 0.00469, 0.0307, 0.00845, 0.0137]
# [False, False, False, False, False, False, False, False]
# [0.0402, 0.0385, 0.464, 0.00545, 0.359, 0.0242, -1, -1, 0.00546]
# [False, False, False, False, False, False, False, False, False]
# [0.029, 0.0244, 0.0204, 0.0323, -1, 0.612, 0.0383]
# [False, False, False, False, False, False, False]
# [0.00967, 0.355, 0.0241, 0.19, 0.0016]
# [False, False, False, False, False]
# [0.0523, 0.0327, 0.0703, 0.999, 0.00264, -1]
# [False, False, False, True, False, False]
# [0.0337, 0.00736, 0.0051, 0.041, 0.0445, 0.00541, 0.665, -1]
# [False, False, False, False, False, False, False, False]
# [0.0305, 0.0195, 0.0201, 0.00438, 0.00453, -1, 0.00846, 0.00552, -1]
# [False, False, False, False, False, False, False, False, False]
# [0.0224, 0.0768, 0.0686, 0.063, 0.813, -1]
# [False, False, False, False, True, False]
# [0.0268, 0.605, 0.962, 0.0312, 0.0385, 0.951]
# [False, False, True, False, False, True]
# [0.836, 0.0241, 0.0281, 0.00263, 0.242, ..., 0.00531, 0.993, -1, -1, -1]
# [True, False, False, False, False, False, ..., False, True, False, False, False]
# [0.019, 0.0508, 0.0251, 0.916, 0.00431, -1, -1, -1, 0.765, -1]
# [False, False, False, True, False, False, False, False, False, False]
# [0.068, 0.0669, 0.0255, 0.406, 0.12, 0.00905, -1, 0.0435, -1]
# [False, False, False, False, False, False, False, False, False]
# [0.0144, 0.0157, 0.973, 0.923, 0.00227]
# [False, False, True, True, False]
# [0.0284, 0.999, 0.992, 0.143, 0.0246, 0.00735, -1]
# [False, True, True, False, False, False, False]
# [0.00544, 0.94, 0.999, 0.00178]
# [False, True, True, False]
# [0.0449, 0.155, 0.0693, 0.288, -1, 0.00756, -1]
# [False, False, False, False, False, False, False]
# [0.0325, 0.0233, 0.0173, 0.00663, 1, 0.00501, 0.0206, -1]
# [False, False, False, False, True, False, False, False]
# [0.0215, 0.0249, 0.0239, 0.0396, 0.00291, 0.0132, 0.012]
# [False, False, False, False, False, False, False]
# [0.0355, 0.0212, 0.342, 0.999, 0.013, 0.0122, 0.0189, 0.0238]
# [False, False, False, True, False, False, False, False]
# [0.745, 0.0239, 0.215, 0.995, -1]
# [False, False, False, True, False]
# [0.997, 0.0576, 0.0226, 1, 0.00557, 0.00468, -1, -1]
# [True, False, False, True, False, False, False, False]
# [0.0221, 0.709, 0.00354, 0.0481, 0.994, ..., 0.186, 0.0136, 0.0135, -1, -1]
# [False, False, False, False, True, ..., False, False, False, False, False]
# [0.996, 0.106, 0.0263, 0.0508]
# [True, False, False, False]
# [0.00505, 0.0591, 0.0247, 0.982, 0.00626, 0.253, 0.182]
# [False, False, False, True, False, False, False]
# [0.05, 0.917, 0.0172, 0.0112, 0.999, ..., 0.0276, 0.00184, 0.0266, 0.0108]
# [False, True, False, False, True, False, False, False, False, False]
# [0.991, 0.0768, 0.0221, 0.15, -1]
# [True, False, False, False, False]
# [0.937, 0.0687, 0.0322, 0.999, 0.00544, -1, 0.00544]
# [True, False, False, True, False, False, False]
# [0.0104, 0.0323, 0.911, 0.0098, 0.996, 0.0223, 0.00759, 0.0249]
# [False, False, True, False, True, False, False, False]
# [0.0486, 0.0263, 0.828, 0.0137, 1, 0.00483, 0.0635]
# [False, False, True, False, True, False, False]
# [0.0285, 0.928, 0.03, 0.0104, 0.0142, 0.00153, 0.0176, 0.0242, -1]
# [False, True, False, False, False, False, False, False, False]
# [0.0209, 0.0854, 0.0231, 0.0156, -1, -1, 0.0205]
# [False, False, False, False, False, False, False]
# [0.055, 0.0269, 0.0308, 0.568, 0.999, 0.0124, -1, -1]
# [False, False, False, False, True, False, False, False]
# [0.0228, 0.046, 0.953, 0.997, 0.118, 0.01, -1, -1, 0.00681, -1, -1]
# [False, False, True, True, False, False, False, False, False, False, False]
# [0.233, 0.0252, 0.00942, 0.0321, 1, 0.00666, 0.994, 0.00531, -1, -1]
# [False, False, False, False, True, False, True, False, False, False]
# [0.0249, 1, 0.616, 1, 0.00354, 0.00404, -1, 0.0274, 0.174]
# [False, True, False, True, False, False, False, False, False]
# [0.0346, 0.0235, 0.00343, 0.828, 0.999, 0.00214, 0.0186, 0.0145, 0.156, -1]
# [False, False, False, True, True, False, False, False, False, False]
# [0.0269, 0.44, 0.999, 0.00512, 0.0409, -1, -1]
# [False, False, True, False, False, False, False]
# [0.0286, 0.165, 0.0247, 0.859]
# [False, False, False, True]
# [0.0241, 0.805, 0.96, 0.00538, 0.0153, -1]
# [False, True, True, False, False, False]
# [0.0217, 0.235, 0.0201, 0.00803, 0.0042, 0.992, 0.0759, 0.688, 0.0869, -1]
# [False, False, False, False, False, True, False, False, False, False]
# [0.0474, 0.994, 0.999, 0.0208, 0.00363, -1]
# [False, True, True, False, False, False]
# [0.0263, 0.0229, 0.94, 0.00358, 0.991, 0.0682, 0.00377, 0.747, -1]
# [False, False, True, False, True, False, False, False, False]
# [0.0234, 0.021, 0.0149, 0.842, 0.0864, 0.0388, 0.0207, -1, 0.0271]
# [False, False, False, True, False, False, False, False, False]
# [0.0273, 0.129, 0.986, 0.0355, -1, -1]
# [False, False, True, False, False, False]
# [0.987, 0.0199, 0.993, 0.0111, 0.0302]
# [True, False, True, False, False]
# [0.658, 0.102, 0.0278, 0.99, 0.00398, 0.0114, 0.16, -1, 0.329]
# [False, False, False, True, False, False, False, False, False]
# [0.0356, 0.0162, 0.986, 0.104, 0.0711, -1]
# [False, False, True, False, False, False]
# [0.769, 0.0466, 0.43, 0.0101, 0.0279, ..., 0.0142, 0.0792, 0.0131, 0.00807]
# [False, False, False, False, False, ..., False, False, False, False, False]
# [0.974, 0.0279, 0.658, 0.11]
# [True, False, False, False]
# [0.0545, 0.0236, 0.214, 0.00246, 0.997, 0.00357, 0.0123]
# [False, False, False, False, True, False, False]
# [0.00655, 0.602, 0.375, 0.0234, 0.0255, 0.00974]
# [False, False, False, False, False, False]
# [0.0226, 0.148, 0.022, 0.0066, 0.131, 0.999, 0.0219, 0.00407, 0.00813, -1]
# [False, False, False, False, False, True, False, False, False, False]
# [0.0149, 0.887, 0.0371, 0.945, 0.0145, -1]
# [False, True, False, True, False, False]
# [0.0266, 0.434, 0.481, 0.013, 0.0129]
# [False, False, False, False, False]
# [0.0131, 0.0352, 0.02, 0.0125, 0.00391, 0.00419, 1, 0.00857, 0.144]
# [False, False, False, False, False, False, True, False, False]
# [0.0304, 0.0322, 0.983, 0.00948, 0.00292, ..., 0.0127, 0.00433, 0.12, -1, -1]
# [False, False, True, False, False, ..., False, False, False, False, False]
# [0.0161, 0.387, 0.989, 0.0179, 0.0338, 0.00695, 0.0103]
# [False, False, True, False, False, False, False]
# [0.171, 0.0238, 0.0488, 0.00518, -1, 0.00666, -1, -1, 0.00458, -1, -1]
# [False, False, False, False, False, ..., False, False, False, False, False]
# [0.985, 0.233, 0.0225, 0.0458, 0.998, 0.00271, -1]
# [True, False, False, False, True, False, False]
# [0.329, 0.204, 0.025, 0.999, 0.0078, 0.00588, 0.00665, 0.0603]
# [False, False, False, True, False, False, False, False]
# 466 signal btag score
# 3841 all btag score
# 483 all ak4 ak8 drs
# 233 bover08 drs
# all b tag score  3841
# signal Btag score 466
# masked all b tag score 3549

# %% [markdown]
# ### b 안에 lepton 들어가는게 얼마나되는지 확인

# %%
## b jetd은 lhe b와 제일 가까운 b 사용 , lepton은 pt 제일 큰 두개 사용.

from importlib import import_module
import os
import sys
import argparse
import linecache
import uproot
import vector
import math
import numpy as np
import matplotlib.pyplot as plt
import awkward as ak

sample = "/data6/Users/achihwan/LRSM_tb_channel/SAMPLEPRODUCTION/WRtoNMutoMuMuTB-HadTop_MWR-5000_MN-2500_13p6TeV/Run3Summer22NanoAODv12_WRtoNMutoMuMuTB-HadTop_MWR-5000_MN-2500_13p6TeV_1.root"
file = uproot.open(sample)
events = file["Events"]
keys = events.keys()


lhe_pdgid = events["LHEPart_pdgId"].array()
lhe_pt = events["LHEPart_pt"].array()
lhe_eta = events["LHEPart_eta"].array()
lhe_phi = events["LHEPart_phi"].array()
lhe_mass = events["LHEPart_mass"].array()
lhe_status = events["LHEPart_status"].array()

ak4_eta = events["Jet_eta"].array()
ak4_phi = events["Jet_phi"].array()
ak4_pt = events["Jet_pt"].array()
ak4_flavor = events["Jet_hadronFlavour"].array()
ak4_mass = events["Jet_mass"].array()
btag = events["Jet_btagPNetB"].array()

## Fatjet 
fatjet_pt = events["FatJet_pt"].array()
fatjet_eta = events["FatJet_eta"].array()
fatjet_phi = events["FatJet_phi"].array()
fatjet_mass = events["FatJet_mass"].array()

gen_pdgid = events["GenPart_pdgId"].array()
gen_pt = events["GenPart_pt"].array()
gen_eta = events["GenPart_eta"].array()
gen_phi = events["GenPart_phi"].array()

reco_muon_pt = events["Muon_pt"].array()
reco_muon_eta = events["Muon_eta"].array()
reco_muon_phi = events["Muon_phi"].array()
reco_muon_mass = events["Muon_mass"].array()

def fdphi(phi1, phi2):
    d = phi1 - phi2
    # wrap to [-π, +π]
    return (d + np.pi) % (2*np.pi) - np.pi

def fdr(eta1, phi1, eta2, phi2):
    d_eta = eta1 - eta2
    d_phi = fdphi(phi1, phi2)
    return np.sqrt(d_eta**2 + d_phi**2)

# mask 
bottom_mask = (lhe_pdgid == 5) | (lhe_pdgid == -5)
bottom_eta = lhe_eta[bottom_mask]
bottom_phi = lhe_phi[bottom_mask]
bottom_pt = lhe_pt[bottom_mask]
bottom_mass = lhe_mass[bottom_mask]

topmask = (gen_pdgid == 6) | (gen_pdgid == -6)
top_eta = gen_eta[topmask]
top_phi1 = gen_phi[topmask]

bottompt = bottom_pt[:, 1]#bottom quark 1 = WR* mother
bottometa = bottom_eta[:, 1]
bottomphi = bottom_phi[:, 1]
bottommass = bottom_mass[:, 1]

muon_mask = (lhe_pdgid == 13) | (lhe_pdgid == -13)
muon_pt = lhe_pt[muon_mask]
muon_eta = lhe_eta[muon_mask]
muon_phi = lhe_phi[muon_mask]
muon_mass = lhe_mass[muon_mask]

n_mother_muon_mass = muon_mass[:,0] # muon 1 = WR* mother
n_mother_muon_pt = muon_pt[:,0] # muon 1 = WR* mother
n_mother_muon_eta = muon_eta[:,0]
n_mother_muon_phi = muon_phi[:,0]

WR_mother_muon_mass = muon_mass[:,1] # muon 2 = WR* mother
WR_mother_muon_pt = muon_pt[:,1] # muon 2 = WR* mother
WR_mother_muon_eta = muon_eta[:,1]
WR_mother_muon_phi = muon_phi[:,1]  

valid_events = 0. # ak4 jet 있고 , 뮤온도 두개인 이벤트 
cleaned = 0
for i in range(len(bottompt)):
        if (len(ak4_pt[i]) == 0) or ((bottompt[i]) == False) or (len(top_eta[i]) < 2):
            continue
        delta_eta = bottometa[i] - ak4_eta[i]
        delta_phi = bottomphi[i] - ak4_phi[i] 
        delta_phi = (delta_phi + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
        dr = np.sqrt(delta_eta**2 + delta_phi**2)

        delta_eta = bottometa[i] - ak4_eta[i]
        delta_phi = bottomphi[i] - ak4_phi[i] 
        delta_phi = (delta_phi + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
        dr = np.sqrt(delta_eta**2 + delta_phi**2)

        top_etas = top_eta[i][0]
        top_phi = top_phi1[i][0]
        delta_etas = fatjet_eta[i] - top_etas
        delta_phis = fatjet_phi[i] -top_phi 
        delta_phis = (delta_phis + np.pi) % (2 * np.pi) - np.pi  # wrap to [-π, +π]
        dr_jet = np.sqrt(delta_etas**2 + delta_phis**2)

        if len(dr) == 0: 
            continue
        if len(reco_muon_pt[i]) < 2:
            continue
        valid_events += 1
        idxb = np.argsort(dr)[0] ## bottom과 제일 가까운 ak4 jet
        idx_mu1 = np.argsort(reco_muon_pt[i])[-1] ## 
        idx_mu2 = np.argsort(reco_muon_pt[i])[-2] ## 
        #print(bottometa[i], bottomphi[i], reco_muon_eta[i][idx_mu1], reco_muon_phi[i][idx_mu1])
        dr1 = fdr(bottometa[i], bottomphi[i], reco_muon_eta[i][idx_mu1], reco_muon_phi[i][idx_mu1])
        dr2 = fdr(bottometa[i], bottomphi[i], reco_muon_eta[i][idx_mu2], reco_muon_phi[i][idx_mu2])
        if dr1 > 0.4 or dr2 > 0.4:
            cleaned += 1
print(f"Valid events: {valid_events}, Cleaned events: {cleaned}")
# Out:
# Valid events: 489.0, Cleaned events: 488
